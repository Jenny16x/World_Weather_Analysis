# %%
import random
from citipy import citipy
import numpy as np
from config import weather_api_key
import requests
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# miandrivazo mg
# barrow us
# busselton au
# vila franca do campo pt
# kapaa us
# vaini to
# roebourne au
# asau tv
# korla cn
# ushuaia ar
# odweyne so
# chokurdakh ru
# punta arenas cl
# arraial do cabo br
# mar del plata ar
# olafsvik is
# mar del plata ar
# raton us
# berlevag no
# rikitea pf
# mar del plata ar
# kieta pg
# port alfred za
# khonuu ru
# beloha mg
# ushuaia ar
# kapaa us
# sentyabrskiy ru
# ostrovnoy ru
# hilo us
# tiksi ru
# rikitea pf
# te anau nz
# cabo san lucas mx
# tasiilaq gl
# hobart au
# albany au
# kirakira sb
# bahia blanca ar
# qaanaaq gl
# avarua ck
# kruisfontein za
# gazojak tm
# tasiilaq gl
# butiama tz
# qaanaaq gl
# hay river ca
# arraial do cabo br
# meulaboh id
# antigonish ca
# nikolskoye ru
# saint-philippe re
# bengkulu id
# waingapu id
# marion us
# salalah om
# mar del plata ar
# albany au
# hobart au
# klaksvik fo
# bengkulu id
# tumannyy ru
# avarua ck
# nikolayevka ru
# victoria sc
# okhotsk ru
# calama cl
# impfondo cg
# desbiens ca
# bentiu sd
# punta arenas cl
# luderitz na
# puerto baquerizo moreno ec
# rikitea pf
# saint-philippe re
# stornoway gb
# samarai pg
# arraial do cabo br
# bluff nz
# mataura pf
# mataura pf
# faya td
# port alfred za
# rikitea pf
# ust-nera ru
# saint george bm
# mys shmidta ru
# vaini to
# turayf sa
# santa rosa ar
# iqaluit ca
# amderma ru
# busselton au
# alofi nu
# darab ir
# plettenberg bay za
# yellowknife ca
# klyuchi ru
# nikolskoye ru
# hilo us
# fortuna us
# albany au
# rikitea pf
# jamestown sh
# lebu cl
# walvis bay na
# kavaratti in
# halifax ca
# rikitea pf
# sao filipe cv
# rikitea pf
# dhidhdhoo mv
# pringsewu id
# kasama zm
# lushunkou cn
# pisco pe
# qaanaaq gl
# butaritari ki
# hilo us
# qaanaaq gl
# saldanha za
# calceta ec
# pevek ru
# nizhneyansk ru
# miquelon pm
# zhuanghe cn
# gat ly
# hithadhoo mv
# geraldton au
# busselton au
# buqayq sa
# luderitz na
# troitsko-pechorsk ru
# disna by
# aksarka ru
# kodiak us
# mys shmidta ru
# naron es
# qaanaaq gl
# tasiilaq gl
# khatanga ru
# ushuaia ar
# nome us
# raudeberg no
# lebu cl
# mapimi mx
# ushuaia ar
# paita nc
# lambarene ga
# bluff nz
# qaanaaq gl
# molo ke
# port hedland au
# kaitangata nz
# brae gb
# taolanaro mg
# punta arenas cl
# provideniya ru
# puerto ayora ec
# grand river south east mu
# cabo san lucas mx
# saint-philippe re
# butaritari ki
# hobart au
# avarua ck
# atuona pf
# georgetown sh
# mataura pf
# port augusta au
# iqaluit ca
# port elizabeth za
# lavrentiya ru
# andenes no
# castro cl
# lyantonde ug
# atuona pf
# new norfolk au
# ballina ie
# samusu ws
# saldanha za
# lebu cl
# jamestown sh
# el tarra co
# price us
# ouro fino br
# ushuaia ar
# new norfolk au
# lasa cn
# fartura br
# zaysan kz
# iqaluit ca
# carinhanha br
# hermanus za
# carnarvon au
# mataura pf
# stokmarknes no
# port alfred za
# rikitea pf
# new norfolk au
# mataura pf
# barrow us
# mataura pf
# airai pw
# aripuana br
# mahebourg mu
# sola vu
# thompson ca
# cherskiy ru
# atuona pf
# aklavik ca
# concepcion del oro mx
# clyde river ca
# lao cai vn
# punta arenas cl
# kyzyl-suu kg
# kodiak us
# punta arenas cl
# samokov mk
# port alfred za
# hermanus za
# bengkulu id
# ixtapa mx
# rocha uy
# homer us
# ilulissat gl
# vaini to
# arlit ne
# vaini to
# bethel us
# padang id
# blagoyevo ru
# torbay ca
# ribeira grande pt
# esperance au
# east london za
# rikitea pf
# cape town za
# atuona pf
# ushuaia ar
# tuktoyaktuk ca
# ribeira grande pt
# mount gambier au
# jamestown sh
# bojnurd ir
# busselton au
# ushuaia ar
# yarmouth ca
# tuktoyaktuk ca
# luderitz na
# punta arenas cl
# avarua ck
# ushuaia ar
# new norfolk au
# lebu cl
# dicabisagan ph
# lamu ke
# severo-kurilsk ru
# ituango co
# bluff nz
# yomitan jp
# qaanaaq gl
# rikitea pf
# kapaa us
# east london za
# yellowknife ca
# cidreira br
# lompoc us
# rikitea pf
# avarua ck
# jamestown sh
# atuona pf
# jamestown sh
# punta arenas cl
# tessalit ml
# choix mx
# ushuaia ar
# mutsamudu km
# cabot us
# fortuna us
# atuona pf
# mataura pf
# butaritari ki
# ushuaia ar
# grand river south east mu
# shelburne ca
# rajapur in
# vaitupu wf
# bereda so
# khatanga ru
# nuuk gl
# qaanaaq gl
# taolanaro mg
# qaqortoq gl
# petropavlovsk-kamchatskiy ru
# takoradi gh
# puerto ayora ec
# faanui pf
# busselton au
# lavrentiya ru
# nago jp
# vaini to
# vaini to
# atuona pf
# saint-philippe re
# vaini to
# inhambane mz
# kahului us
# kalmunai lk
# richards bay za
# christchurch nz
# saskylakh ru
# mar del plata ar
# lorengau pg
# port alfred za
# vaini to
# hithadhoo mv
# kapaa us
# albany au
# kodiak us
# nikolskoye ru
# bethel us
# atuona pf
# cidreira br
# pathein mm
# canhotinho br
# ribeira grande pt
# east london za
# tuktoyaktuk ca
# bafq ir
# mar del plata ar
# flinders au
# cubarral co
# igarka ru
# luanda ao
# hithadhoo mv
# hermanus za
# tsihombe mg
# port alfred za
# ushuaia ar
# hermanus za
# ostrovnoy ru
# rikitea pf
# purpe ru
# port alfred za
# mataura pf
# kruisfontein za
# hay river ca
# fare pf
# avarua ck
# east london za
# salym ru
# kaitangata nz
# zeya ru
# barentsburg sj
# dikson ru
# hermanus za
# avarua ck
# avarua ck
# busselton au
# atuona pf
# hami cn
# grasse fr
# mataura pf
# nikolskoye ru
# vao nc
# cidreira br
# georgetown sh
# cape town za
# meulaboh id
# bardstown us
# port elizabeth za
# mount isa au
# kavieng pg
# yellowknife ca
# mataura pf
# abu kamal sy
# halalo wf
# laguna br
# bethel us
# quatre cocos mu
# bluff nz
# saint george bm
# hermanus za
# punta arenas cl
# lebu cl
# trat th
# ilulissat gl
# agadez ne
# tuatapere nz
# ketchenery ru
# ushuaia ar
# bagotville ca
# kodiak us
# hermanus za
# barrancabermeja co
# hobart au
# upernavik gl
# taolanaro mg
# mys shmidta ru
# mangalam in
# albany au
# airai pw
# ahipara nz
# atbasar kz
# atuona pf
# sitka us
# anadyr ru
# alekseyevsk ru
# chokurdakh ru
# jurm af
# carnarvon au
# vaini to
# mar del plata ar
# airai pw
# palmerston au
# port elizabeth za
# mount isa au
# linjiang cn
# cienfuegos cu
# jaque pa
# souillac mu
# mataura pf
# atar mr
# rikitea pf
# kerchevskiy ru
# hermanus za
# rikitea pf
# busselton au
# sentyabrskiy ru
# butaritari ki
# jamestown sh
# rikitea pf
# vaini to
# hermanus za
# pevek ru
# lulea se
# abu dhabi ae
# bluff nz
# illoqqortoormiut gl
# mahebourg mu
# ust-shonosha ru
# illoqqortoormiut gl
# fare pf
# severo-kurilsk ru
# vaitupu wf
# saldanha za
# new norfolk au
# hasaki jp
# mys shmidta ru
# arraial do cabo br
# faanui pf
# butaritari ki
# yellowknife ca
# campo gobierno mx
# punta arenas cl
# evanston us
# sangar ru
# jamestown sh
# arraial do cabo br
# hithadhoo mv
# chuy uy
# malanje ao
# lebu cl
# qaanaaq gl
# georgetown sh
# samusu ws
# bonthe sl
# carnarvon au
# ponta do sol cv
# cherskiy ru
# samalaeulu ws
# atuona pf
# busselton au
# luderitz na
# san cristobal ec
# sembe cg
# antalaha mg
# valmiera lv
# jamestown sh
# belyy yar ru
# baykit ru
# new norfolk au
# rikitea pf
# chuy uy
# bredasdorp za
# kapaa us
# nikolskoye ru
# hilo us
# rikitea pf
# amahai id
# barentsburg sj
# busselton au
# nanortalik gl
# taolanaro mg
# ngunguru nz
# naze jp
# butaritari ki
# norman wells ca
# komsomolskiy ru
# hobart au
# pevek ru
# kushiro jp
# butaritari ki
# fort saint james ca
# peniche pt
# arraial do cabo br
# nilai my
# hong gai vn
# canton us
# tapaua br
# bredasdorp za
# rikitea pf
# georgetown sh
# port hedland au
# balykshi kz
# ribeira grande pt
# jamestown sh
# trelew ar
# thompson ca
# cape town za
# ghedi it
# bluff nz
# lebu cl
# port alfred za
# kabanjahe id
# sola vu
# saldanha za
# tuktoyaktuk ca
# mataura pf
# talavera de la reina es
# poum nc
# mandalgovi mn
# port alfred za
# goure ne
# aksarka ru
# santa rosa ar
# bluff nz
# college us
# ushuaia ar
# new norfolk au
# barrow us
# taolanaro mg
# barrow us
# illoqqortoormiut gl
# albany au
# raudeberg no
# mataura pf
# ushuaia ar
# bluff nz
# brae gb
# srandakan id
# punta arenas cl
# souillac mu
# bredasdorp za
# nikolskoye ru
# san cristobal ec
# taolanaro mg
# port alfred za
# hobart au
# rikitea pf
# saint-philippe re
# kavieng pg
# rikitea pf
# severo-kurilsk ru
# ushuaia ar
# deputatskiy ru
# hobart au
# mujiayingzi cn
# taolanaro mg
# taolanaro mg
# mogadishu so
# thompson ca
# cap-haitien ht
# yar-sale ru
# torbay ca
# mithimna gr
# nouadhibou mr
# atuona pf
# iroquois falls ca
# hasaki jp
# port alfred za
# kodiak us
# castro cl
# severo-kurilsk ru
# albany au
# puerto ayora ec
# barrow us
# yellowknife ca
# tuktoyaktuk ca
# khash ir
# izmaylovo ru
# nizhneyansk ru
# belushya guba ru
# salalah om
# ribeira grande pt
# vilyuysk ru
# bolshoye sorokino ru
# bathsheba bb
# arraial do cabo br
# albany au
# attawapiskat ca
# hobart au
# ploemeur fr
# sinkat sd
# ushuaia ar
# ballina au
# atuona pf
# ketchikan us
# cape town za
# hilo us
# cidreira br
# punta arenas cl
# ushuaia ar
# barrow us
# constitucion mx
# rio claro tt
# ribeira grande pt
# punta arenas cl
# georgetown sh
# airai pw
# rikitea pf
# hami cn
# paraiso mx
# athabasca ca
# raudeberg no
# barrow us
# pevek ru
# jamestown sh
# shibarghan af
# bhabua in
# jacmel ht
# saskylakh ru
# nara ml
# ponta do sol cv
# sola vu
# bilibino ru
# bluff nz
# petatlan mx
# aklavik ca
# kaeo nz
# hilo us
# hasaki jp
# qaanaaq gl
# fairbanks us
# kapaa us
# east london za
# ribeira grande pt
# dianopolis br
# ushuaia ar
# amderma ru
# ushuaia ar
# katsuura jp
# wanning cn
# laguna br
# avarua ck
# katsuura jp
# mataura pf
# comodoro rivadavia ar
# port elizabeth za

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 747

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + city.replace(" ", "+")
city_weather = requests.get(city_url).json()
print(city_weather)
# Out:
# {'coord': {'lon': 25.5701, 'lat': -33.918}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 64.69, 'feels_like': 63.82, 'temp_min': 64.69, 'temp_max': 65.1, 'pressure': 1006, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 240}, 'clouds': {'all': 0}, 'dt': 1634920067, 'sys': {'type': 1, 'id': 1973, 'country': 'ZA', 'sunrise': 1634873256, 'sunset': 1634920587}, 'timezone': 7200, 'id': 964420, 'name': 'Port Elizabeth', 'cod': 200}

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | miandrivazo
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | vila franca do campo
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | roebourne
# Processing Record 8 of Set 1 | asau
# Processing Record 9 of Set 1 | korla
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | odweyne
# Processing Record 12 of Set 1 | chokurdakh
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | olafsvik
# Processing Record 17 of Set 1 | raton
# Processing Record 18 of Set 1 | berlevag
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | kieta
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 1 | beloha
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | ostrovnoy
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | tiksi
# Processing Record 28 of Set 1 | te anau
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | kirakira
# Processing Record 34 of Set 1 | bahia blanca
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | kruisfontein
# Processing Record 38 of Set 1 | gazojak
# Processing Record 39 of Set 1 | butiama
# Processing Record 40 of Set 1 | hay river
# Processing Record 41 of Set 1 | meulaboh
# Processing Record 42 of Set 1 | antigonish
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | waingapu
# Processing Record 47 of Set 1 | marion
# Processing Record 48 of Set 1 | salalah
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 2 | nikolayevka
# Processing Record 2 of Set 2 | victoria
# Processing Record 3 of Set 2 | okhotsk
# Processing Record 4 of Set 2 | calama
# Processing Record 5 of Set 2 | impfondo
# Processing Record 6 of Set 2 | desbiens
# Processing Record 7 of Set 2 | bentiu
# Processing Record 8 of Set 2 | luderitz
# Processing Record 9 of Set 2 | puerto baquerizo moreno
# Processing Record 10 of Set 2 | stornoway
# Processing Record 11 of Set 2 | samarai
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | faya
# Processing Record 15 of Set 2 | ust-nera
# Processing Record 16 of Set 2 | saint george
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | turayf
# Processing Record 19 of Set 2 | santa rosa
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | alofi
# Processing Record 23 of Set 2 | darab
# Processing Record 24 of Set 2 | plettenberg bay
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | klyuchi
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | walvis bay
# Processing Record 31 of Set 2 | kavaratti
# Processing Record 32 of Set 2 | halifax
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | dhidhdhoo
# Processing Record 35 of Set 2 | pringsewu
# Processing Record 36 of Set 2 | kasama
# Processing Record 37 of Set 2 | lushunkou
# City not found. Skipping...
# Processing Record 38 of Set 2 | pisco
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | calceta
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 2 | miquelon
# Processing Record 45 of Set 2 | zhuanghe
# Processing Record 46 of Set 2 | gat
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | geraldton
# Processing Record 49 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 50 of Set 2 | troitsko-pechorsk
# Processing Record 1 of Set 3 | disna
# Processing Record 2 of Set 3 | aksarka
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | naron
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | raudeberg
# Processing Record 8 of Set 3 | mapimi
# Processing Record 9 of Set 3 | paita
# Processing Record 10 of Set 3 | lambarene
# Processing Record 11 of Set 3 | molo
# Processing Record 12 of Set 3 | port hedland
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | brae
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 3 | provideniya
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | port augusta
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | andenes
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | lyantonde
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | ballina
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | el tarra
# Processing Record 31 of Set 3 | price
# Processing Record 32 of Set 3 | ouro fino
# Processing Record 33 of Set 3 | lasa
# Processing Record 34 of Set 3 | fartura
# Processing Record 35 of Set 3 | zaysan
# Processing Record 36 of Set 3 | carinhanha
# Processing Record 37 of Set 3 | hermanus
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | stokmarknes
# Processing Record 40 of Set 3 | airai
# Processing Record 41 of Set 3 | aripuana
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | sola
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | aklavik
# Processing Record 47 of Set 3 | concepcion del oro
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | lao cai
# Processing Record 50 of Set 3 | kyzyl-suu
# Processing Record 1 of Set 4 | samokov
# Processing Record 2 of Set 4 | ixtapa
# Processing Record 3 of Set 4 | rocha
# Processing Record 4 of Set 4 | homer
# Processing Record 5 of Set 4 | ilulissat
# Processing Record 6 of Set 4 | arlit
# Processing Record 7 of Set 4 | bethel
# Processing Record 8 of Set 4 | padang
# Processing Record 9 of Set 4 | blagoyevo
# Processing Record 10 of Set 4 | torbay
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | cape town
# Processing Record 15 of Set 4 | tuktoyaktuk
# Processing Record 16 of Set 4 | mount gambier
# Processing Record 17 of Set 4 | bojnurd
# Processing Record 18 of Set 4 | yarmouth
# Processing Record 19 of Set 4 | dicabisagan
# Processing Record 20 of Set 4 | lamu
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | ituango
# Processing Record 23 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 24 of Set 4 | cidreira
# Processing Record 25 of Set 4 | lompoc
# Processing Record 26 of Set 4 | tessalit
# Processing Record 27 of Set 4 | choix
# Processing Record 28 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 29 of Set 4 | cabot
# Processing Record 30 of Set 4 | shelburne
# Processing Record 31 of Set 4 | rajapur
# Processing Record 32 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 4 | bereda
# Processing Record 34 of Set 4 | nuuk
# Processing Record 35 of Set 4 | qaqortoq
# Processing Record 36 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 4 | takoradi
# Processing Record 38 of Set 4 | faanui
# Processing Record 39 of Set 4 | nago
# Processing Record 40 of Set 4 | inhambane
# Processing Record 41 of Set 4 | kahului
# Processing Record 42 of Set 4 | kalmunai
# Processing Record 43 of Set 4 | richards bay
# Processing Record 44 of Set 4 | christchurch
# Processing Record 45 of Set 4 | saskylakh
# Processing Record 46 of Set 4 | lorengau
# Processing Record 47 of Set 4 | pathein
# Processing Record 48 of Set 4 | canhotinho
# Processing Record 49 of Set 4 | bafq
# Processing Record 50 of Set 4 | flinders
# Processing Record 1 of Set 5 | cubarral
# Processing Record 2 of Set 5 | igarka
# Processing Record 3 of Set 5 | luanda
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | purpe
# Processing Record 6 of Set 5 | fare
# Processing Record 7 of Set 5 | salym
# Processing Record 8 of Set 5 | zeya
# Processing Record 9 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 5 | dikson
# Processing Record 11 of Set 5 | hami
# Processing Record 12 of Set 5 | grasse
# Processing Record 13 of Set 5 | vao
# Processing Record 14 of Set 5 | bardstown
# Processing Record 15 of Set 5 | mount isa
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | abu kamal
# Processing Record 18 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 5 | laguna
# Processing Record 20 of Set 5 | quatre cocos
# Processing Record 21 of Set 5 | verkhnyaya inta
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | boyolangu
# Processing Record 24 of Set 5 | semey
# Processing Record 25 of Set 5 | hambantota
# Processing Record 26 of Set 5 | grand gaube
# Processing Record 27 of Set 5 | zalantun
# Processing Record 28 of Set 5 | cururupu
# Processing Record 29 of Set 5 | arinos
# Processing Record 30 of Set 5 | alice springs
# Processing Record 31 of Set 5 | yatou
# Processing Record 32 of Set 5 | mehamn
# Processing Record 33 of Set 5 | ponta do sol
# Processing Record 34 of Set 5 | komsomolskiy
# Processing Record 35 of Set 5 | namatanai
# Processing Record 36 of Set 5 | norman wells
# Processing Record 37 of Set 5 | bredasdorp
# Processing Record 38 of Set 5 | tura
# Processing Record 39 of Set 5 | beyneu
# Processing Record 40 of Set 5 | west wendover
# Processing Record 41 of Set 5 | nantucket
# Processing Record 42 of Set 5 | vila do maio
# Processing Record 43 of Set 5 | varnamo
# Processing Record 44 of Set 5 | pak chong
# Processing Record 45 of Set 5 | the pas
# Processing Record 46 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 47 of Set 5 | karasjok
# Processing Record 48 of Set 5 | ancud
# Processing Record 49 of Set 5 | ghorawal
# Processing Record 50 of Set 5 | yeppoon
# Processing Record 1 of Set 6 | kinsale
# Processing Record 2 of Set 6 | codrington
# Processing Record 3 of Set 6 | grand baie
# Processing Record 4 of Set 6 | atar
# Processing Record 5 of Set 6 | sabang
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | bagaha
# Processing Record 8 of Set 6 | ambilobe
# Processing Record 9 of Set 6 | campbell river
# Processing Record 10 of Set 6 | ewa beach
# Processing Record 11 of Set 6 | srednekolymsk
# Processing Record 12 of Set 6 | gamba
# Processing Record 13 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 14 of Set 6 | manzanillo
# Processing Record 15 of Set 6 | kaffrine
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | prince rupert
# Processing Record 18 of Set 6 | grindavik
# Processing Record 19 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 6 | taoudenni
# Processing Record 21 of Set 6 | lima
# Processing Record 22 of Set 6 | las vegas
# Processing Record 23 of Set 6 | upata
# Processing Record 24 of Set 6 | sinnamary
# Processing Record 25 of Set 6 | fallon
# Processing Record 26 of Set 6 | yablonovo
# Processing Record 27 of Set 6 | bulgan
# Processing Record 28 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 6 | mucurapo
# Processing Record 30 of Set 6 | buchanan
# Processing Record 31 of Set 6 | vila velha
# Processing Record 32 of Set 6 | hasaki
# Processing Record 33 of Set 6 | kenai
# Processing Record 34 of Set 6 | puli
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | cayenne
# Processing Record 37 of Set 6 | niimi
# Processing Record 38 of Set 6 | san cristobal
# Processing Record 39 of Set 6 | yar-sale
# Processing Record 40 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 6 | storebo
# Processing Record 42 of Set 6 | road town
# Processing Record 43 of Set 6 | sao jose da coroa grande
# Processing Record 44 of Set 6 | merrill
# Processing Record 45 of Set 6 | tucurui
# Processing Record 46 of Set 6 | grand-lahou
# Processing Record 47 of Set 6 | mantua
# Processing Record 48 of Set 6 | takapau
# Processing Record 49 of Set 6 | galesong
# Processing Record 50 of Set 6 | usinsk
# Processing Record 1 of Set 7 | trat
# Processing Record 2 of Set 7 | agadez
# Processing Record 3 of Set 7 | ketchenery
# City not found. Skipping...
# Processing Record 4 of Set 7 | bagotville
# Processing Record 5 of Set 7 | barrancabermeja
# Processing Record 6 of Set 7 | upernavik
# Processing Record 7 of Set 7 | mangalam
# Processing Record 8 of Set 7 | ahipara
# Processing Record 9 of Set 7 | atbasar
# Processing Record 10 of Set 7 | sitka
# Processing Record 11 of Set 7 | anadyr
# Processing Record 12 of Set 7 | alekseyevsk
# Processing Record 13 of Set 7 | jurm
# Processing Record 14 of Set 7 | palmerston
# Processing Record 15 of Set 7 | linjiang
# Processing Record 16 of Set 7 | cienfuegos
# Processing Record 17 of Set 7 | jaque
# Processing Record 18 of Set 7 | souillac
# Processing Record 19 of Set 7 | kerchevskiy
# Processing Record 20 of Set 7 | lulea
# Processing Record 21 of Set 7 | abu dhabi
# Processing Record 22 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 7 | ust-shonosha
# Processing Record 24 of Set 7 | campo gobierno
# Processing Record 25 of Set 7 | evanston
# Processing Record 26 of Set 7 | sangar
# Processing Record 27 of Set 7 | chuy
# Processing Record 28 of Set 7 | malanje
# Processing Record 29 of Set 7 | bonthe
# Processing Record 30 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 7 | sembe
# Processing Record 32 of Set 7 | antalaha
# Processing Record 33 of Set 7 | valmiera
# Processing Record 34 of Set 7 | belyy yar
# Processing Record 35 of Set 7 | baykit
# Processing Record 36 of Set 7 | amahai
# Processing Record 37 of Set 7 | nanortalik
# Processing Record 38 of Set 7 | ngunguru
# Processing Record 39 of Set 7 | naze
# Processing Record 40 of Set 7 | kushiro
# Processing Record 41 of Set 7 | fort saint james
# Processing Record 42 of Set 7 | peniche
# Processing Record 43 of Set 7 | nilai
# Processing Record 44 of Set 7 | hong gai
# Processing Record 45 of Set 7 | canton
# Processing Record 46 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 47 of Set 7 | balykshi
# Processing Record 48 of Set 7 | trelew
# Processing Record 49 of Set 7 | ghedi
# Processing Record 50 of Set 7 | kabanjahe
# Processing Record 1 of Set 8 | talavera de la reina
# Processing Record 2 of Set 8 | poum
# Processing Record 3 of Set 8 | mandalgovi
# Processing Record 4 of Set 8 | goure
# Processing Record 5 of Set 8 | college
# Processing Record 6 of Set 8 | srandakan
# Processing Record 7 of Set 8 | deputatskiy
# Processing Record 8 of Set 8 | mujiayingzi
# Processing Record 9 of Set 8 | mogadishu
# Processing Record 10 of Set 8 | sao miguel do araguaia
# Processing Record 11 of Set 8 | vaikam
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | marzuq
# Processing Record 14 of Set 8 | wewak
# Processing Record 15 of Set 8 | sergeyevka
# Processing Record 16 of Set 8 | diourbel
# Processing Record 17 of Set 8 | mandan
# Processing Record 18 of Set 8 | caraballeda
# Processing Record 19 of Set 8 | henties bay
# Processing Record 20 of Set 8 | north bend
# Processing Record 21 of Set 8 | naryan-mar
# Processing Record 22 of Set 8 | noyabrsk
# Processing Record 23 of Set 8 | dezhou
# Processing Record 24 of Set 8 | broome
# Processing Record 25 of Set 8 | okulovka
# Processing Record 26 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 27 of Set 8 | fort nelson
# Processing Record 28 of Set 8 | araxa
# Processing Record 29 of Set 8 | katsuura
# Processing Record 30 of Set 8 | west point
# Processing Record 31 of Set 8 | shibetsu
# Processing Record 32 of Set 8 | vorukh
# Processing Record 33 of Set 8 | port macquarie
# Processing Record 34 of Set 8 | chickasha
# Processing Record 35 of Set 8 | guadalajara
# Processing Record 36 of Set 8 | zhangjiakou
# Processing Record 37 of Set 8 | svobodnyy
# Processing Record 38 of Set 8 | dedza
# Processing Record 39 of Set 8 | nelson bay
# Processing Record 40 of Set 8 | natchitoches
# Processing Record 41 of Set 8 | saint-pierre
# Processing Record 42 of Set 8 | gobabis
# Processing Record 43 of Set 8 | nivala
# Processing Record 44 of Set 8 | shahrud
# Processing Record 45 of Set 8 | emerald
# Processing Record 46 of Set 8 | ust-kuyga
# Processing Record 47 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 8 | paamiut
# Processing Record 49 of Set 8 | popondetta
# Processing Record 50 of Set 8 | teya
# Processing Record 1 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 2 of Set 9 | topeka
# Processing Record 3 of Set 9 | toora-khem
# Processing Record 4 of Set 9 | miyako
# Processing Record 5 of Set 9 | dunedin
# Processing Record 6 of Set 9 | jiaonan
# Processing Record 7 of Set 9 | da lat
# Processing Record 8 of Set 9 | buala
# Processing Record 9 of Set 9 | touros
# Processing Record 10 of Set 9 | vila
# Processing Record 11 of Set 9 | kropotkin
# Processing Record 12 of Set 9 | chernyshevskiy
# Processing Record 13 of Set 9 | isangel
# Processing Record 14 of Set 9 | humaita
# Processing Record 15 of Set 9 | santa maria
# Processing Record 16 of Set 9 | la ronge
# Processing Record 17 of Set 9 | elko
# Processing Record 18 of Set 9 | juneau
# Processing Record 19 of Set 9 | ntoum
# Processing Record 20 of Set 9 | vikhorevka
# Processing Record 21 of Set 9 | jinji
# Processing Record 22 of Set 9 | acari
# Processing Record 23 of Set 9 | jiwani
# Processing Record 24 of Set 9 | los llanos de aridane
# Processing Record 25 of Set 9 | saint anthony
# Processing Record 26 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 27 of Set 9 | zhaocheng
# City not found. Skipping...
# Processing Record 28 of Set 9 | tambo
# Processing Record 29 of Set 9 | blairmore
# Processing Record 30 of Set 9 | kobojango
# City not found. Skipping...
# Processing Record 31 of Set 9 | razole
# Processing Record 32 of Set 9 | xining
# Processing Record 33 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 9 | lagoa
# Processing Record 35 of Set 9 | alboraya
# Processing Record 36 of Set 9 | patrocinio
# Processing Record 37 of Set 9 | dodge city
# Processing Record 38 of Set 9 | ola
# Processing Record 39 of Set 9 | jamame
# Processing Record 40 of Set 9 | quelimane
# Processing Record 41 of Set 9 | salta
# Processing Record 42 of Set 9 | eyl
# Processing Record 43 of Set 9 | fairbanks
# Processing Record 44 of Set 9 | carora
# Processing Record 45 of Set 9 | vostok
# Processing Record 46 of Set 9 | moose factory
# Processing Record 47 of Set 9 | kulhudhuffushi
# Processing Record 48 of Set 9 | bathsheba
# Processing Record 49 of Set 9 | hurghada
# Processing Record 50 of Set 9 | lampang
# Processing Record 1 of Set 10 | toledo
# Processing Record 2 of Set 10 | tyrma
# Processing Record 3 of Set 10 | yanam
# Processing Record 4 of Set 10 | egvekinot
# Processing Record 5 of Set 10 | lakes entrance
# Processing Record 6 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 10 | rosarito
# Processing Record 8 of Set 10 | dongsheng
# Processing Record 9 of Set 10 | xai-xai
# Processing Record 10 of Set 10 | coquimbo
# Processing Record 11 of Set 10 | san carlos de bariloche
# Processing Record 12 of Set 10 | hamilton
# Processing Record 13 of Set 10 | mananjary
# Processing Record 14 of Set 10 | sorland
# Processing Record 15 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 10 | qujing
# Processing Record 17 of Set 10 | moa
# Processing Record 18 of Set 10 | shimoda
# Processing Record 19 of Set 10 | agaro
# Processing Record 20 of Set 10 | piqua
# Processing Record 21 of Set 10 | dingle
# Processing Record 22 of Set 10 | aykhal
# Processing Record 23 of Set 10 | soloneshnoye
# Processing Record 24 of Set 10 | dubasari
# Processing Record 25 of Set 10 | parati
# Processing Record 26 of Set 10 | havelock
# Processing Record 27 of Set 10 | erzin
# Processing Record 28 of Set 10 | znamenskoye
# Processing Record 29 of Set 10 | mattawa
# Processing Record 30 of Set 10 | charters towers
# Processing Record 31 of Set 10 | hargeysa
# Processing Record 32 of Set 10 | ponot
# Processing Record 33 of Set 10 | puerto carreno
# Processing Record 34 of Set 10 | kasempa
# Processing Record 35 of Set 10 | tuy hoa
# Processing Record 36 of Set 10 | werda
# Processing Record 37 of Set 10 | harper
# Processing Record 38 of Set 10 | pangnirtung
# Processing Record 39 of Set 10 | arkhara
# Processing Record 40 of Set 10 | xingtai
# Processing Record 41 of Set 10 | sabha
# Processing Record 42 of Set 10 | yulara
# Processing Record 43 of Set 10 | tabou
# Processing Record 44 of Set 10 | yenagoa
# Processing Record 45 of Set 10 | shache
# Processing Record 46 of Set 10 | ardesen
# Processing Record 47 of Set 10 | panlaitan
# Processing Record 48 of Set 10 | valvedditturai
# Processing Record 49 of Set 10 | port lincoln
# Processing Record 50 of Set 10 | stykkisholmur
# Processing Record 1 of Set 11 | axim
# Processing Record 2 of Set 11 | huarmey
# Processing Record 3 of Set 11 | turukhansk
# Processing Record 4 of Set 11 | hualmay
# Processing Record 5 of Set 11 | tateyama
# Processing Record 6 of Set 11 | umba
# Processing Record 7 of Set 11 | scituate
# Processing Record 8 of Set 11 | merauke
# Processing Record 9 of Set 11 | usatove
# Processing Record 10 of Set 11 | constitucion
# Processing Record 11 of Set 11 | george
# Processing Record 12 of Set 11 | emba
# Processing Record 13 of Set 11 | husavik
# Processing Record 14 of Set 11 | half moon bay
# Processing Record 15 of Set 11 | yerbogachen
# Processing Record 16 of Set 11 | linhares
# Processing Record 17 of Set 11 | stromness
# Processing Record 18 of Set 11 | jiazi
# Processing Record 19 of Set 11 | udachnyy
# Processing Record 20 of Set 11 | lumeje
# Processing Record 21 of Set 11 | sargatskoye
# Processing Record 22 of Set 11 | kapiri mposhi
# Processing Record 23 of Set 11 | omboue
# Processing Record 24 of Set 11 | crossville
# Processing Record 25 of Set 11 | valparaiso
# Processing Record 26 of Set 11 | uthal
# Processing Record 27 of Set 11 | miyang
# Processing Record 28 of Set 11 | taksimo
# Processing Record 29 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 11 | merzifon
# Processing Record 31 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 11 | san rafael
# Processing Record 34 of Set 11 | anori
# Processing Record 35 of Set 11 | linden
# Processing Record 36 of Set 11 | storm lake
# Processing Record 37 of Set 11 | antofagasta
# Processing Record 38 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 11 | sao mateus do maranhao
# Processing Record 40 of Set 11 | mercedes
# Processing Record 41 of Set 11 | oranjestad
# Processing Record 42 of Set 11 | batemans bay
# Processing Record 43 of Set 11 | andra
# Processing Record 44 of Set 11 | lukovetskiy
# Processing Record 45 of Set 11 | hilton head island
# Processing Record 46 of Set 11 | amot
# Processing Record 47 of Set 11 | pontalina
# Processing Record 48 of Set 11 | vestmannaeyjar
# Processing Record 49 of Set 11 | dongning
# Processing Record 50 of Set 11 | atasu
# Processing Record 1 of Set 12 | pita
# Processing Record 2 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 12 | carstairs
# Processing Record 4 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 5 of Set 12 | nouadhibou
# Processing Record 6 of Set 12 | killybegs
# Processing Record 7 of Set 12 | timmins
# Processing Record 8 of Set 12 | serenje
# Processing Record 9 of Set 12 | akyab
# Processing Record 10 of Set 12 | pueblo nuevo
# Processing Record 11 of Set 12 | kalachinsk
# Processing Record 12 of Set 12 | bowen
# Processing Record 13 of Set 12 | atyashevo
# Processing Record 14 of Set 12 | ullapool
# Processing Record 15 of Set 12 | khandbari
# Processing Record 16 of Set 12 | vardo
# Processing Record 17 of Set 12 | fereydun kenar
# Processing Record 18 of Set 12 | guerande
# Processing Record 19 of Set 12 | ucluelet
# Processing Record 20 of Set 12 | boa vista
# Processing Record 21 of Set 12 | dabakala
# Processing Record 22 of Set 12 | guanica
# Processing Record 23 of Set 12 | salvador
# Processing Record 24 of Set 12 | ginda
# Processing Record 25 of Set 12 | benguela
# Processing Record 26 of Set 12 | atocha
# Processing Record 27 of Set 12 | qianan
# Processing Record 28 of Set 12 | rehoboth
# Processing Record 29 of Set 12 | pozo colorado
# Processing Record 30 of Set 12 | grandview
# Processing Record 31 of Set 12 | yarada
# Processing Record 32 of Set 12 | tlalpujahua
# City not found. Skipping...
# Processing Record 33 of Set 12 | krasnoselkup
# Processing Record 34 of Set 12 | vanimo
# Processing Record 35 of Set 12 | sibolga
# Processing Record 36 of Set 12 | kaduy
# Processing Record 37 of Set 12 | guamuchil
# Processing Record 38 of Set 12 | san patricio
# Processing Record 39 of Set 12 | miraflores
# Processing Record 40 of Set 12 | schladming
# Processing Record 41 of Set 12 | raga
# Processing Record 42 of Set 12 | lichinga
# Processing Record 43 of Set 12 | kandalaksha
# Processing Record 44 of Set 12 | mocuba
# Processing Record 45 of Set 12 | iralaya
# Processing Record 46 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 12 | zlitan
# Processing Record 48 of Set 12 | muroto
# Processing Record 49 of Set 12 | singaraja
# Processing Record 50 of Set 12 | lennoxtown
# Processing Record 1 of Set 13 | san miguel
# Processing Record 2 of Set 13 | chapleau
# Processing Record 3 of Set 13 | kloulklubed
# Processing Record 4 of Set 13 | gornopravdinsk
# Processing Record 5 of Set 13 | bara
# Processing Record 6 of Set 13 | roswell
# Processing Record 7 of Set 13 | ukiah
# Processing Record 8 of Set 13 | elizabeth city
# Processing Record 9 of Set 13 | petatlan
# Processing Record 10 of Set 13 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 11 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 13 | scarborough
# Processing Record 13 of Set 13 | havre-saint-pierre
# Processing Record 14 of Set 13 | omurtag
# Processing Record 15 of Set 13 | saiha
# Processing Record 16 of Set 13 | comodoro rivadavia
# Processing Record 17 of Set 13 | carutapera
# Processing Record 18 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 13 | banda aceh
# Processing Record 20 of Set 13 | jacksonville beach
# Processing Record 21 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 22 of Set 13 | itaituba
# Processing Record 23 of Set 13 | orotukan
# Processing Record 24 of Set 13 | sangmelima
# Processing Record 25 of Set 13 | porto velho
# Processing Record 26 of Set 13 | shenkursk
# Processing Record 27 of Set 13 | kurchum
# Processing Record 28 of Set 13 | nexo
# Processing Record 29 of Set 13 | oranjemund
# Processing Record 30 of Set 13 | camacupa
# Processing Record 31 of Set 13 | itarema
# Processing Record 32 of Set 13 | saint-louis
# Processing Record 33 of Set 13 | shasta lake
# Processing Record 34 of Set 13 | chicama
# Processing Record 35 of Set 13 | takaungu
# Processing Record 36 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 13 | san quintin
# Processing Record 38 of Set 13 | antipovka
# Processing Record 39 of Set 13 | kalianget
# Processing Record 40 of Set 13 | sakakah
# Processing Record 41 of Set 13 | masterton
# Processing Record 42 of Set 13 | isla mujeres
# Processing Record 43 of Set 13 | balotra
# Processing Record 44 of Set 13 | dzhebariki-khaya
# Processing Record 45 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 13 | porto novo
# Processing Record 48 of Set 13 | ketchikan
# Processing Record 49 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 13 | taybad
# Processing Record 1 of Set 14 | jaisalmer
# Processing Record 2 of Set 14 | lodja
# Processing Record 3 of Set 14 | anan
# Processing Record 4 of Set 14 | zaozerne
# Processing Record 5 of Set 14 | avenal
# Processing Record 6 of Set 14 | udarnyy
# Processing Record 7 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 8 of Set 14 | monrovia
# Processing Record 9 of Set 14 | hovd
# Processing Record 10 of Set 14 | gulf gate estates
# Processing Record 11 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 14 | bandarbeyla
# Processing Record 13 of Set 14 | novyy urengoy
# Processing Record 14 of Set 14 | kaoma
# Processing Record 15 of Set 14 | krasnovishersk
# Processing Record 16 of Set 14 | lata
# Processing Record 17 of Set 14 | oyama
# Processing Record 18 of Set 14 | atakpame
# Processing Record 19 of Set 14 | godec
# City not found. Skipping...
# Processing Record 20 of Set 14 | benton harbor
# Processing Record 21 of Set 14 | bayan
# Processing Record 22 of Set 14 | hatillo
# Processing Record 23 of Set 14 | puerto escondido
# Processing Record 24 of Set 14 | port blair
# Processing Record 25 of Set 14 | jacmel
# Processing Record 26 of Set 14 | tazovskiy
# Processing Record 27 of Set 14 | athabasca
# Processing Record 28 of Set 14 | hervey bay
# Processing Record 29 of Set 14 | jovellanos
# Processing Record 30 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 14 | ubinskoye
# Processing Record 32 of Set 14 | skovorodino
# Processing Record 33 of Set 14 | krasni okny
# Processing Record 34 of Set 14 | sokoto
# Processing Record 35 of Set 14 | tanout
# Processing Record 36 of Set 14 | zharkent
# Processing Record 37 of Set 14 | arica
# Processing Record 38 of Set 14 | malatya
# Processing Record 39 of Set 14 | vagay
# Processing Record 40 of Set 14 | killarney
# Processing Record 41 of Set 14 | sao raimundo nonato
# Processing Record 42 of Set 14 | san ramon
# Processing Record 43 of Set 14 | kamenka
# Processing Record 44 of Set 14 | vanavara
# Processing Record 45 of Set 14 | dalvik
# Processing Record 46 of Set 14 | rovaniemi
# Processing Record 47 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 14 | hailey
# Processing Record 49 of Set 14 | daru
# Processing Record 50 of Set 14 | tarutyne
# Processing Record 1 of Set 15 | horn
# Processing Record 2 of Set 15 | mirnyy
# Processing Record 3 of Set 15 | smidovich
# Processing Record 4 of Set 15 | nabire
# Processing Record 5 of Set 15 | boa viagem
# Processing Record 6 of Set 15 | kaspiyskiy
# Processing Record 7 of Set 15 | tres arroyos
# Processing Record 8 of Set 15 | pemberton
# Processing Record 9 of Set 15 | swellendam
# Processing Record 10 of Set 15 | kemijarvi
# Processing Record 11 of Set 15 | hegang
# Processing Record 12 of Set 15 | holland
# Processing Record 13 of Set 15 | los lunas
# Processing Record 14 of Set 15 | cabo rojo
# Processing Record 15 of Set 15 | sobolevo
# Processing Record 16 of Set 15 | san jose
# Processing Record 17 of Set 15 | carbonia
# Processing Record 18 of Set 15 | kiama
# Processing Record 19 of Set 15 | kautokeino
# Processing Record 20 of Set 15 | bayeux
# Processing Record 21 of Set 15 | hobyo
# Processing Record 22 of Set 15 | rongcheng
# Processing Record 23 of Set 15 | calvinia
# Processing Record 24 of Set 15 | togur
# Processing Record 25 of Set 15 | kelvington
# Processing Record 26 of Set 15 | sar-e pul
# Processing Record 27 of Set 15 | paracuru
# Processing Record 28 of Set 15 | altay
# Processing Record 29 of Set 15 | rudnichnyy
# Processing Record 30 of Set 15 | wanganui
# Processing Record 31 of Set 15 | cap-haitien
# Processing Record 32 of Set 15 | mithimna
# City not found. Skipping...
# Processing Record 33 of Set 15 | iroquois falls
# Processing Record 34 of Set 15 | khash
# Processing Record 35 of Set 15 | izmaylovo
# Processing Record 36 of Set 15 | vilyuysk
# Processing Record 37 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 38 of Set 15 | ploemeur
# Processing Record 39 of Set 15 | rio claro
# Processing Record 40 of Set 15 | paraiso
# Processing Record 41 of Set 15 | shibarghan
# City not found. Skipping...
# Processing Record 42 of Set 15 | bhabua
# Processing Record 43 of Set 15 | nara
# Processing Record 44 of Set 15 | bilibino
# Processing Record 45 of Set 15 | kaeo
# Processing Record 46 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 47 of Set 15 | wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# city_url = url + "&q=" + city.replace(" ", "+")
# city_weather = requests.get(city_url).json()
# city_weather

# %%
city_data
# Out:
# [{'City': 'Miandrivazo',
#   'Lat': -19.5167,
#   'Lng': 45.4667,
#   'Max Temp': 76.28,
#   'Current Description': 'few clouds',
#   'Humidity': 56,
#   'Cloudiness': 17,
#   'Wind Speed': 8.48,
#   'Country': 'MG'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 26.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 50.09,
#   'Current Description': 'clear sky',
#   'Humidity': 74,
#   'Cloudiness': 7,
#   'Wind Speed': 7.36,
#   'Country': 'AU'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 70.21,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 8,
#   'Wind Speed': 5.82,
#   'Country': 'PT'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.52,
#   'Current Description': 'light rain',
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'US'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 69.96,
#   'Current Description': 'scattered clouds',
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'TO'},
#  {'City': 'Roebourne',
#   'Lat': -20.7833,
#   'Lng': 117.1333,
#   'Max Temp': 81.52,
#   'Current Description': 'few clouds',
#   'Humidity': 32,
#   'Cloudiness': 20,
#   'Wind Speed': 7.09,
#   'Country': 'AU'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 60.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Country': 'RO'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 59.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 22,
#   'Cloudiness': 95,
#   'Wind Speed': 14.72,
#   'Country': 'CN'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 49.66,
#   'Current Description': 'scattered clouds',
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 24.16,
#   'Country': 'AR'},
#  {'City': 'Odweyne',
#   'Lat': 9.4092,
#   'Lng': 45.064,
#   'Max Temp': 76.24,
#   'Current Description': 'scattered clouds',
#   'Humidity': 49,
#   'Cloudiness': 43,
#   'Wind Speed': 16.28,
#   'Country': 'SO'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -14.98,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 96,
#   'Wind Speed': 2.3,
#   'Country': 'RU'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 48.31,
#   'Current Description': 'broken clouds',
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 36.82,
#   'Country': 'CL'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 76.96,
#   'Current Description': 'clear sky',
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'BR'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 59.09,
#   'Current Description': 'moderate rain',
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'AR'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 41.45,
#   'Current Description': 'heavy intensity rain',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 22.82,
#   'Country': 'IS'},
#  {'City': 'Raton',
#   'Lat': 36.9034,
#   'Lng': -104.4391,
#   'Max Temp': 66.58,
#   'Current Description': 'clear sky',
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 33.8,
#   'Current Description': 'light shower snow',
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'NO'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.92,
#   'Current Description': 'light rain',
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 24.14,
#   'Country': 'PF'},
#  {'City': 'Kieta',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 77,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Country': 'PG'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 65.08,
#   'Current Description': 'broken clouds',
#   'Humidity': 80,
#   'Cloudiness': 61,
#   'Wind Speed': 8.79,
#   'Country': 'ZA'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 67.59,
#   'Current Description': 'scattered clouds',
#   'Humidity': 70,
#   'Cloudiness': 27,
#   'Wind Speed': 13.56,
#   'Country': 'MG'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 34.95,
#   'Current Description': 'overcast clouds',
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 23.31,
#   'Country': 'RU'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 73.27,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 3.31,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Country': 'RU'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 45.09,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.87,
#   'Country': 'NZ'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 82.51,
#   'Current Description': 'clear sky',
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'MX'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 35.76,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.5,
#   'Country': 'GL'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 58.12,
#   'Current Description': 'moderate rain',
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'AU'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 62.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 68,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 78.31,
#   'Current Description': 'broken clouds',
#   'Humidity': 78,
#   'Cloudiness': 82,
#   'Wind Speed': 7.58,
#   'Country': 'SB'},
#  {'City': 'Bahia Blanca',
#   'Lat': -38.7196,
#   'Lng': -62.2724,
#   'Max Temp': 65.82,
#   'Current Description': 'overcast clouds',
#   'Humidity': 36,
#   'Cloudiness': 97,
#   'Wind Speed': 13.65,
#   'Country': 'AR'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -1.61,
#   'Current Description': 'clear sky',
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 8.43,
#   'Country': 'GL'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 69.85,
#   'Current Description': 'broken clouds',
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CK'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 62.89,
#   'Current Description': 'few clouds',
#   'Humidity': 68,
#   'Cloudiness': 23,
#   'Wind Speed': 5.46,
#   'Country': 'ZA'},
#  {'City': 'Gazojak',
#   'Lat': 41.1875,
#   'Lng': 61.4036,
#   'Max Temp': 48.18,
#   'Current Description': 'few clouds',
#   'Humidity': 31,
#   'Cloudiness': 16,
#   'Wind Speed': 7.74,
#   'Country': 'TM'},
#  {'City': 'Butiama',
#   'Lat': -1.7667,
#   'Lng': 33.9667,
#   'Max Temp': 68.18,
#   'Current Description': 'light rain',
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 6.35,
#   'Country': 'TZ'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 39.18,
#   'Current Description': 'broken clouds',
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CA'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 76.73,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Country': 'ID'},
#  {'City': 'Antigonish',
#   'Lat': 45.6169,
#   'Lng': -61.9986,
#   'Max Temp': 67.82,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'CA'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 47.88,
#   'Current Description': 'light rain',
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 18.92,
#   'Country': 'RU'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 76.59,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 85,
#   'Wind Speed': 7.36,
#   'Country': 'RE'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 76.66,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Country': 'ID'},
#  {'City': 'Waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 79.95,
#   'Current Description': 'broken clouds',
#   'Humidity': 81,
#   'Cloudiness': 72,
#   'Wind Speed': 3.78,
#   'Country': 'ID'},
#  {'City': 'Marion',
#   'Lat': 39.7684,
#   'Lng': -86.1555,
#   'Max Temp': 54.18,
#   'Current Description': 'mist',
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 78.89,
#   'Current Description': 'clear sky',
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'OM'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 38.32,
#   'Current Description': 'broken clouds',
#   'Humidity': 54,
#   'Cloudiness': 81,
#   'Wind Speed': 5.44,
#   'Country': 'FO'},
#  {'City': 'Nikolayevka',
#   'Lat': 53.1257,
#   'Lng': 47.2041,
#   'Max Temp': 53.73,
#   'Current Description': 'overcast clouds',
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 17.07,
#   'Country': 'RU'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 68.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'HK'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 19.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.21,
#   'Country': 'RU'},
#  {'City': 'Calama',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 72.09,
#   'Current Description': 'clear sky',
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 21.85,
#   'Country': 'CL'},
#  {'City': 'Impfondo',
#   'Lat': 1.6381,
#   'Lng': 18.0667,
#   'Max Temp': 75.65,
#   'Current Description': 'scattered clouds',
#   'Humidity': 81,
#   'Cloudiness': 45,
#   'Wind Speed': 0.56,
#   'Country': 'CG'},
#  {'City': 'Desbiens',
#   'Lat': 48.4178,
#   'Lng': -71.9495,
#   'Max Temp': 46.15,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 14.67,
#   'Country': 'CA'},
#  {'City': 'Bentiu',
#   'Lat': 9.2333,
#   'Lng': 29.8333,
#   'Max Temp': 80.04,
#   'Current Description': 'scattered clouds',
#   'Humidity': 62,
#   'Cloudiness': 50,
#   'Wind Speed': 5.03,
#   'Country': 'SS'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 60.44,
#   'Current Description': 'clear sky',
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 11.14,
#   'Country': 'NA'},
#  {'City': 'Puerto Baquerizo Moreno',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 70.79,
#   'Current Description': 'light rain',
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'EC'},
#  {'City': 'Stornoway',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 47.93,
#   'Current Description': 'broken clouds',
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'GB'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 81.05,
#   'Current Description': 'overcast clouds',
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Country': 'PG'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 48.42,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 2.37,
#   'Country': 'NZ'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 43.97,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 1.95,
#   'Country': 'NZ'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 69.91,
#   'Current Description': 'clear sky',
#   'Humidity': 25,
#   'Cloudiness': 4,
#   'Wind Speed': 13.2,
#   'Country': 'SA'},
#  {'City': 'Ust-Nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': 5.67,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 3.4,
#   'Country': 'RU'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 71.55,
#   'Current Description': 'clear sky',
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Turayf',
#   'Lat': 31.6725,
#   'Lng': 38.6637,
#   'Max Temp': 75.45,
#   'Current Description': 'clear sky',
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'SA'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 81.1,
#   'Current Description': 'broken clouds',
#   'Humidity': 78,
#   'Cloudiness': 73,
#   'Wind Speed': 7.29,
#   'Country': 'PH'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 26.33,
#   'Current Description': 'broken clouds',
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 18.99,
#   'Country': 'CA'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 69.69,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'NU'},
#  {'City': 'Darab',
#   'Lat': 28.7519,
#   'Lng': 54.5444,
#   'Max Temp': 72.99,
#   'Current Description': 'clear sky',
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 5.08,
#   'Country': 'IR'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 62.47,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 93,
#   'Wind Speed': 3.24,
#   'Country': 'ZA'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 38.41,
#   'Current Description': 'few clouds',
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'CA'},
#  {'City': 'Klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 39.29,
#   'Current Description': 'broken clouds',
#   'Humidity': 43,
#   'Cloudiness': 55,
#   'Wind Speed': 16.69,
#   'Country': 'RU'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 56.43,
#   'Current Description': 'broken clouds',
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 5.99,
#   'Country': 'US'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 49.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01,
#   'Country': 'US'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.96,
#   'Current Description': 'broken clouds',
#   'Humidity': 64,
#   'Cloudiness': 76,
#   'Wind Speed': 18.03,
#   'Country': 'CL'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 67.15,
#   'Current Description': 'clear sky',
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'NA'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 82.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 75,
#   'Cloudiness': 36,
#   'Wind Speed': 2.39,
#   'Country': 'IN'},
#  {'City': 'Halifax',
#   'Lat': 44.6453,
#   'Lng': -63.5724,
#   'Max Temp': 71.42,
#   'Current Description': 'broken clouds',
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 8.99,
#   'Country': 'CA'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 84.16,
#   'Current Description': 'clear sky',
#   'Humidity': 58,
#   'Cloudiness': 2,
#   'Wind Speed': 8.9,
#   'Country': 'CV'},
#  {'City': 'Dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 82.06,
#   'Current Description': 'broken clouds',
#   'Humidity': 75,
#   'Cloudiness': 81,
#   'Wind Speed': 5.03,
#   'Country': 'MV'},
#  {'City': 'Pringsewu',
#   'Lat': -5.3582,
#   'Lng': 104.9744,
#   'Max Temp': 74.68,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Country': 'ID'},
#  {'City': 'Kasama',
#   'Lat': -10.2129,
#   'Lng': 31.1808,
#   'Max Temp': 81.64,
#   'Current Description': 'overcast clouds',
#   'Humidity': 24,
#   'Cloudiness': 85,
#   'Wind Speed': 2.39,
#   'Country': 'ZM'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 67.01,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'PE'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.77,
#   'Current Description': 'moderate rain',
#   'Humidity': 79,
#   'Cloudiness': 19,
#   'Wind Speed': 16.82,
#   'Country': 'KI'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 60.85,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 21.72,
#   'Country': 'ZA'},
#  {'City': 'Calceta',
#   'Lat': -0.85,
#   'Lng': -80.1667,
#   'Max Temp': 78.71,
#   'Current Description': 'overcast clouds',
#   'Humidity': 62,
#   'Cloudiness': 97,
#   'Wind Speed': 3.38,
#   'Country': 'EC'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 13.26,
#   'Current Description': 'light snow',
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Country': 'RU'},
#  {'City': 'Miquelon',
#   'Lat': 47.0975,
#   'Lng': -56.3814,
#   'Max Temp': 55.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 95,
#   'Wind Speed': 11.88,
#   'Country': 'PM'},
#  {'City': 'Zhuanghe',
#   'Lat': 39.7008,
#   'Lng': 122.9911,
#   'Max Temp': 45.28,
#   'Current Description': 'clear sky',
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 5.37,
#   'Country': 'CN'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 74.08,
#   'Current Description': 'few clouds',
#   'Humidity': 100,
#   'Cloudiness': 19,
#   'Wind Speed': 12.1,
#   'Country': 'IL'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.39,
#   'Current Description': 'light rain',
#   'Humidity': 75,
#   'Cloudiness': 24,
#   'Wind Speed': 7.99,
#   'Country': 'MV'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 59.41,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'AU'},
#  {'City': 'Troitsko-Pechorsk',
#   'Lat': 62.7084,
#   'Lng': 56.1964,
#   'Max Temp': 43.07,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.22,
#   'Country': 'RU'},
#  {'City': 'Disna',
#   'Lat': 55.568,
#   'Lng': 28.1971,
#   'Max Temp': 45.23,
#   'Current Description': 'overcast clouds',
#   'Humidity': 69,
#   'Cloudiness': 93,
#   'Wind Speed': 18.03,
#   'Country': 'BY'},
#  {'City': 'Aksarka',
#   'Lat': 66.5606,
#   'Lng': 67.7975,
#   'Max Temp': 28.15,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 8.88,
#   'Country': 'RU'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 42.31,
#   'Current Description': 'overcast clouds',
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 21.85,
#   'Country': 'US'},
#  {'City': 'Naron',
#   'Lat': 43.5167,
#   'Lng': -8.1528,
#   'Max Temp': 65.68,
#   'Current Description': 'clear sky',
#   'Humidity': 66,
#   'Cloudiness': 4,
#   'Wind Speed': 12.17,
#   'Country': 'ES'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -0.56,
#   'Current Description': 'broken clouds',
#   'Humidity': 99,
#   'Cloudiness': 77,
#   'Wind Speed': 4.54,
#   'Country': 'RU'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 32.07,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US'},
#  {'City': 'Raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 45.27,
#   'Current Description': 'overcast clouds',
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'NO'},
#  {'City': 'Mapimi',
#   'Lat': 25.8167,
#   'Lng': -103.85,
#   'Max Temp': 70.57,
#   'Current Description': 'clear sky',
#   'Humidity': 57,
#   'Cloudiness': 4,
#   'Wind Speed': 5.21,
#   'Country': 'MX'},
#  {'City': 'Paita',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 73.96,
#   'Current Description': 'scattered clouds',
#   'Humidity': 72,
#   'Cloudiness': 50,
#   'Wind Speed': 12.33,
#   'Country': 'PE'},
#  {'City': 'Lambarene',
#   'Lat': -0.7001,
#   'Lng': 10.2406,
#   'Max Temp': 75.61,
#   'Current Description': 'moderate rain',
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'GA'},
#  {'City': 'Molo',
#   'Lat': -0.2479,
#   'Lng': 35.7374,
#   'Max Temp': 54.18,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 3.38,
#   'Country': 'KE'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 75.25,
#   'Current Description': 'scattered clouds',
#   'Humidity': 53,
#   'Cloudiness': 38,
#   'Wind Speed': 5.75,
#   'Country': 'AU'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 44.83,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Country': 'NZ'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 44.51,
#   'Current Description': 'overcast clouds',
#   'Humidity': 60,
#   'Cloudiness': 88,
#   'Wind Speed': 17.18,
#   'Country': 'GB'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 24.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 11.77,
#   'Country': 'RU'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 76.96,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 91,
#   'Wind Speed': 9.98,
#   'Country': 'EC'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.01,
#   'Current Description': 'scattered clouds',
#   'Humidity': 76,
#   'Cloudiness': 33,
#   'Wind Speed': 21.88,
#   'Country': 'PF'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 79.9,
#   'Current Description': 'scattered clouds',
#   'Humidity': 90,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'MY'},
#  {'City': 'Port Augusta',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 57.7,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 10,
#   'Wind Speed': 15.79,
#   'Country': 'AU'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 65.1,
#   'Current Description': 'clear sky',
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'ZA'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 23.11,
#   'Current Description': 'overcast clouds',
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.86,
#   'Country': 'RU'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 35.58,
#   'Current Description': 'clear sky',
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'NO'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 72.9,
#   'Current Description': 'clear sky',
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 0.29,
#   'Country': 'BR'},
#  {'City': 'Lyantonde',
#   'Lat': -0.4031,
#   'Lng': 31.1572,
#   'Max Temp': 66.4,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 2.17,
#   'Country': 'UG'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 57.76,
#   'Current Description': 'heavy intensity rain',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 0.18,
#   'Country': 'AU'},
#  {'City': 'Ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 69.76,
#   'Current Description': 'broken clouds',
#   'Humidity': 96,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'AU'},
#  {'City': 'El Tarra',
#   'Lat': 8.5756,
#   'Lng': -73.0949,
#   'Max Temp': 90.36,
#   'Current Description': 'broken clouds',
#   'Humidity': 53,
#   'Cloudiness': 64,
#   'Wind Speed': 2.37,
#   'Country': 'CO'},
#  {'City': 'Price',
#   'Lat': 39.5994,
#   'Lng': -110.8107,
#   'Max Temp': 55.06,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Ouro Fino',
#   'Lat': -22.2831,
#   'Lng': -46.3692,
#   'Max Temp': 77.63,
#   'Current Description': 'scattered clouds',
#   'Humidity': 43,
#   'Cloudiness': 38,
#   'Wind Speed': 3.44,
#   'Country': 'BR'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 56.28,
#   'Current Description': 'scattered clouds',
#   'Humidity': 76,
#   'Cloudiness': 31,
#   'Wind Speed': 2.44,
#   'Country': 'IT'},
#  {'City': 'Fartura',
#   'Lat': -23.3883,
#   'Lng': -49.51,
#   'Max Temp': 80.04,
#   'Current Description': 'clear sky',
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 4.27,
#   'Country': 'BR'},
#  {'City': 'Zaysan',
#   'Lat': 47.4667,
#   'Lng': 84.8667,
#   'Max Temp': 37.63,
#   'Current Description': 'light rain',
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'KZ'},
#  {'City': 'Carinhanha',
#   'Lat': -14.3047,
#   'Lng': -43.765,
#   'Max Temp': 85.91,
#   'Current Description': 'overcast clouds',
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 4.34,
#   'Country': 'BR'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 64.8,
#   'Current Description': 'overcast clouds',
#   'Humidity': 72,
#   'Cloudiness': 97,
#   'Wind Speed': 27.29,
#   'Country': 'ZA'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 68.07,
#   'Current Description': 'clear sky',
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'AU'},
#  {'City': 'Stokmarknes',
#   'Lat': 68.5646,
#   'Lng': 14.9108,
#   'Max Temp': 36.5,
#   'Current Description': 'clear sky',
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'NO'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 63,
#   'Current Description': 'broken clouds',
#   'Humidity': 80,
#   'Cloudiness': 82,
#   'Wind Speed': 2.3,
#   'Country': 'TL'},
#  {'City': 'Aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 90.39,
#   'Current Description': 'overcast clouds',
#   'Humidity': 54,
#   'Cloudiness': 87,
#   'Wind Speed': 4.61,
#   'Country': 'BR'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 75.49,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'MU'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 80.13,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 87,
#   'Wind Speed': 6.26,
#   'Country': 'VU'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 30.36,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'CA'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -6.25,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Country': 'RU'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 32.83,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 2.98,
#   'Country': 'CA'},
#  {'City': 'Concepcion Del Oro',
#   'Lat': 24.6333,
#   'Lng': -101.4167,
#   'Max Temp': 64.69,
#   'Current Description': 'overcast clouds',
#   'Humidity': 52,
#   'Cloudiness': 97,
#   'Wind Speed': 4.21,
#   'Country': 'MX'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 26.83,
#   'Current Description': 'overcast clouds',
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'Lao Cai',
#   'Lat': 22.4833,
#   'Lng': 103.95,
#   'Max Temp': 62.67,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.38,
#   'Country': 'VN'},
#  {'City': 'Kyzyl-Suu',
#   'Lat': 42.3414,
#   'Lng': 78.0056,
#   'Max Temp': 31.08,
#   'Current Description': 'light snow',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Country': 'KG'},
#  {'City': 'Samokov',
#   'Lat': 42.3333,
#   'Lng': 23.55,
#   'Max Temp': 54.01,
#   'Current Description': 'broken clouds',
#   'Humidity': 74,
#   'Cloudiness': 82,
#   'Wind Speed': 3.91,
#   'Country': 'BG'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 87.22,
#   'Current Description': 'clear sky',
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'MX'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 75.16,
#   'Current Description': 'clear sky',
#   'Humidity': 46,
#   'Cloudiness': 6,
#   'Wind Speed': 2.39,
#   'Country': 'UY'},
#  {'City': 'Homer',
#   'Lat': 59.6425,
#   'Lng': -151.5483,
#   'Max Temp': 38.77,
#   'Current Description': 'clear sky',
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 21.22,
#   'Current Description': 'broken clouds',
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'GL'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 100.9,
#   'Current Description': 'clear sky',
#   'Humidity': 9,
#   'Cloudiness': 3,
#   'Wind Speed': 1.05,
#   'Country': 'NE'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 70.2,
#   'Current Description': 'few clouds',
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 78.48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.14,
#   'Country': 'ID'},
#  {'City': 'Blagoyevo',
#   'Lat': 63.3667,
#   'Lng': 47.9167,
#   'Max Temp': 42.64,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.78,
#   'Country': 'RU'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 55.89,
#   'Current Description': 'scattered clouds',
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'CA'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 72,
#   'Current Description': 'few clouds',
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'PT'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 51.64,
#   'Current Description': 'broken clouds',
#   'Humidity': 71,
#   'Cloudiness': 64,
#   'Wind Speed': 7.02,
#   'Country': 'AU'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 65.34,
#   'Current Description': 'clear sky',
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ZA'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 60.12,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'ZA'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 23,
#   'Current Description': 'broken clouds',
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'CA'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 51.71,
#   'Current Description': 'broken clouds',
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'AU'},
#  {'City': 'Bojnurd',
#   'Lat': 37.4747,
#   'Lng': 57.329,
#   'Max Temp': 44.55,
#   'Current Description': 'clear sky',
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'IR'},
#  {'City': 'Yarmouth',
#   'Lat': 41.7057,
#   'Lng': -70.2286,
#   'Max Temp': 73.45,
#   'Current Description': 'scattered clouds',
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 8.99,
#   'Country': 'US'},
#  {'City': 'Dicabisagan',
#   'Lat': 17.0818,
#   'Lng': 122.4157,
#   'Max Temp': 76.77,
#   'Current Description': 'broken clouds',
#   'Humidity': 90,
#   'Cloudiness': 69,
#   'Wind Speed': 5.35,
#   'Country': 'PH'},
#  {'City': 'Lamu',
#   'Lat': -2.2717,
#   'Lng': 40.902,
#   'Max Temp': 80.82,
#   'Current Description': 'broken clouds',
#   'Humidity': 77,
#   'Cloudiness': 58,
#   'Wind Speed': 11.92,
#   'Country': 'KE'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 37.13,
#   'Current Description': 'scattered clouds',
#   'Humidity': 75,
#   'Cloudiness': 45,
#   'Wind Speed': 10.67,
#   'Country': 'RU'},
#  {'City': 'Ituango',
#   'Lat': 7.1712,
#   'Lng': -75.764,
#   'Max Temp': 69.08,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 1.32,
#   'Country': 'CO'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 71.78,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 7.83,
#   'Country': 'BR'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 63.01,
#   'Current Description': 'clear sky',
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Tessalit',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 94.77,
#   'Current Description': 'clear sky',
#   'Humidity': 16,
#   'Cloudiness': 3,
#   'Wind Speed': 9.86,
#   'Country': 'ML'},
#  {'City': 'Choix',
#   'Lat': 26.7092,
#   'Lng': -108.3219,
#   'Max Temp': 88.75,
#   'Current Description': 'clear sky',
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 1.25,
#   'Country': 'MX'},
#  {'City': 'Cabot',
#   'Lat': 34.9745,
#   'Lng': -92.0165,
#   'Max Temp': 67.57,
#   'Current Description': 'clear sky',
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 42.67,
#   'Current Description': 'broken clouds',
#   'Humidity': 80,
#   'Cloudiness': 79,
#   'Wind Speed': 8.75,
#   'Country': 'CA'},
#  {'City': 'Rajapur',
#   'Lat': 25.3833,
#   'Lng': 81.15,
#   'Max Temp': 75.27,
#   'Current Description': 'clear sky',
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 4.09,
#   'Country': 'IN'},
#  {'City': 'Bereda',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 61,
#   'Current Description': 'scattered clouds',
#   'Humidity': 88,
#   'Cloudiness': 33,
#   'Wind Speed': 5.86,
#   'Country': 'ES'},
#  {'City': 'Nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 32.61,
#   'Current Description': 'sand',
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 32.21,
#   'Country': 'GL'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 36.1,
#   'Current Description': 'light rain',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.16,
#   'Country': 'GL'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 23.59,
#   'Current Description': 'few clouds',
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 4.47,
#   'Country': 'RU'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 81.37,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 93,
#   'Wind Speed': 11.45,
#   'Country': 'GH'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.01,
#   'Current Description': 'light rain',
#   'Humidity': 79,
#   'Cloudiness': 12,
#   'Wind Speed': 8.81,
#   'Country': 'PF'},
#  {'City': 'Nago',
#   'Lat': 26.5881,
#   'Lng': 127.9761,
#   'Max Temp': 73.56,
#   'Current Description': 'overcast clouds',
#   'Humidity': 57,
#   'Cloudiness': 99,
#   'Wind Speed': 13.56,
#   'Country': 'JP'},
#  {'City': 'Inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 75.18,
#   'Current Description': 'scattered clouds',
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'MZ'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 75.85,
#   'Current Description': 'few clouds',
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 80.04,
#   'Current Description': 'few clouds',
#   'Humidity': 83,
#   'Cloudiness': 14,
#   'Wind Speed': 7.18,
#   'Country': 'LK'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 76.23,
#   'Current Description': 'overcast clouds',
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 15.37,
#   'Country': 'ZA'},
#  {'City': 'Christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 52.95,
#   'Current Description': 'overcast clouds',
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'NZ'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -0.83,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'RU'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 80.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 9.69,
#   'Country': 'PG'},
#  {'City': 'Pathein',
#   'Lat': 16.7833,
#   'Lng': 94.7333,
#   'Max Temp': 74.95,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 3.65,
#   'Country': 'MM'},
#  {'City': 'Canhotinho',
#   'Lat': -8.8822,
#   'Lng': -36.1911,
#   'Max Temp': 82.49,
#   'Current Description': 'broken clouds',
#   'Humidity': 53,
#   'Cloudiness': 78,
#   'Wind Speed': 10.54,
#   'Country': 'BR'},
#  {'City': 'Bafq',
#   'Lat': 31.6128,
#   'Lng': 55.4107,
#   'Max Temp': 61.52,
#   'Current Description': 'clear sky',
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 7.29,
#   'Country': 'IR'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 61.81,
#   'Current Description': 'clear sky',
#   'Humidity': 87,
#   'Cloudiness': 6,
#   'Wind Speed': 1.01,
#   'Country': 'AU'},
#  {'City': 'Cubarral',
#   'Lat': 3.7935,
#   'Lng': -73.8406,
#   'Max Temp': 82.63,
#   'Current Description': 'overcast clouds',
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73,
#   'Country': 'CO'},
#  {'City': 'Igarka',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': 29.62,
#   'Current Description': 'snow',
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 12.46,
#   'Country': 'RU'},
#  {'City': 'Luanda',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 80.6,
#   'Current Description': 'scattered clouds',
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'AO'},
#  {'City': 'Purpe',
#   'Lat': 64.4803,
#   'Lng': 76.6897,
#   'Max Temp': 31.86,
#   'Current Description': 'light snow',
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 9.24,
#   'Country': 'RU'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 78.96,
#   'Current Description': 'light rain',
#   'Humidity': 77,
#   'Cloudiness': 22,
#   'Wind Speed': 13.33,
#   'Country': 'PF'},
#  {'City': 'Salym',
#   'Lat': 60.0625,
#   'Lng': 71.4789,
#   'Max Temp': 33.75,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 9.98,
#   'Country': 'RU'},
#  {'City': 'Zeya',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 33.17,
#   'Current Description': 'scattered clouds',
#   'Humidity': 87,
#   'Cloudiness': 45,
#   'Wind Speed': 1.81,
#   'Country': 'RU'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 18.1,
#   'Current Description': 'overcast clouds',
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 12.77,
#   'Country': 'RU'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 58.96,
#   'Current Description': 'clear sky',
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 3.56,
#   'Country': 'CN'},
#  {'City': 'Grasse',
#   'Lat': 43.6667,
#   'Lng': 6.9167,
#   'Max Temp': 61.59,
#   'Current Description': 'clear sky',
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'FR'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 72.21,
#   'Current Description': 'clear sky',
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95,
#   'Country': 'NC'},
#  {'City': 'Bardstown',
#   'Lat': 37.8092,
#   'Lng': -85.4669,
#   'Max Temp': 58.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 82.17,
#   'Current Description': 'thunderstorm',
#   'Humidity': 39,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'AU'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 80.44,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 8.39,
#   'Country': 'PG'},
#  {'City': 'Abu Kamal',
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp': 75.43,
#   'Current Description': 'clear sky',
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 6.08,
#   'Country': 'SY'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 60.3,
#   'Current Description': 'mist',
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 75.31,
#   'Current Description': 'broken clouds',
#   'Humidity': 76,
#   'Cloudiness': 84,
#   'Wind Speed': 8.68,
#   'Country': 'MU'},
#  {'City': 'Verkhnyaya Inta',
#   'Lat': 65.9811,
#   'Lng': 60.3094,
#   'Max Temp': 28.81,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 11.5,
#   'Country': 'RU'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 47.48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 4.18,
#   'Country': 'NZ'},
#  {'City': 'Boyolangu',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 75.79,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 94,
#   'Wind Speed': 3.67,
#   'Country': 'ID'},
#  {'City': 'Semey',
#   'Lat': 50.4111,
#   'Lng': 80.2275,
#   'Max Temp': 39.42,
#   'Current Description': 'broken clouds',
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'KZ'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 80.62,
#   'Current Description': 'scattered clouds',
#   'Humidity': 82,
#   'Cloudiness': 27,
#   'Wind Speed': 10.18,
#   'Country': 'LK'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 75.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 89,
#   'Wind Speed': 1.99,
#   'Country': 'MU'},
#  {'City': 'Zalantun',
#   'Lat': 48,
#   'Lng': 122.7167,
#   'Max Temp': 36.75,
#   'Current Description': 'clear sky',
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'CN'},
#  {'City': 'Cururupu',
#   'Lat': -1.8283,
#   'Lng': -44.8683,
#   'Max Temp': 91.33,
#   'Current Description': 'overcast clouds',
#   'Humidity': 46,
#   'Cloudiness': 99,
#   'Wind Speed': 7.43,
#   'Country': 'BR'},
#  {'City': 'Arinos',
#   'Lat': -15.9169,
#   'Lng': -46.1056,
#   'Max Temp': 92.95,
#   'Current Description': 'scattered clouds',
#   'Humidity': 34,
#   'Cloudiness': 31,
#   'Wind Speed': 2.44,
#   'Country': 'BR'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 81.95,
#   'Current Description': 'scattered clouds',
#   'Humidity': 18,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'AU'},
#  {'City': 'Yatou',
#   'Lat': 37.15,
#   'Lng': 122.3833,
#   'Max Temp': 49.57,
#   'Current Description': 'light rain',
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'CN'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 35.78,
#   'Current Description': 'snow',
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 25.32,
#   'Country': 'NO'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 73.71,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 5.5,
#   'Country': 'PT'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 48.92,
#   'Current Description': 'scattered clouds',
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'UZ'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 77.72,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 4.63,
#   'Country': 'PG'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 39.24,
#   'Current Description': 'broken clouds',
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'CA'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 64.27,
#   'Current Description': 'overcast clouds',
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 18.12,
#   'Country': 'ZA'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 66,
#   'Current Description': 'clear sky',
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 4.07,
#   'Country': 'IN'},
#  {'City': 'Beyneu',
#   'Lat': 45.3167,
#   'Lng': 55.2,
#   'Max Temp': 55.99,
#   'Current Description': 'clear sky',
#   'Humidity': 54,
#   'Cloudiness': 7,
#   'Wind Speed': 12.39,
#   'Country': 'KZ'},
#  {'City': 'West Wendover',
#   'Lat': 40.7391,
#   'Lng': -114.0733,
#   'Max Temp': 43.81,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 71.74,
#   'Current Description': 'broken clouds',
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'US'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 90.39,
#   'Current Description': 'few clouds',
#   'Humidity': 74,
#   'Cloudiness': 15,
#   'Wind Speed': 10.49,
#   'Country': 'CV'},
#  {'City': 'Varnamo',
#   'Lat': 57.186,
#   'Lng': 14.04,
#   'Max Temp': 41.31,
#   'Current Description': 'clear sky',
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 9.98,
#   'Country': 'SE'},
#  {'City': 'Pak Chong',
#   'Lat': 14.708,
#   'Lng': 101.4161,
#   'Max Temp': 73.27,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 8.72,
#   'Country': 'TH'},
#  {'City': 'The Pas',
#   'Lat': 53.8251,
#   'Lng': -101.2541,
#   'Max Temp': 26.62,
#   'Current Description': 'broken clouds',
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'Karasjok',
#   'Lat': 69.4719,
#   'Lng': 25.5112,
#   'Max Temp': 28.51,
#   'Current Description': 'broken clouds',
#   'Humidity': 91,
#   'Cloudiness': 68,
#   'Wind Speed': 6.76,
#   'Country': 'NO'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 59.43,
#   'Current Description': 'few clouds',
#   'Humidity': 56,
#   'Cloudiness': 21,
#   'Wind Speed': 9.19,
#   'Country': 'CL'},
#  {'City': 'Ghorawal',
#   'Lat': 24.7667,
#   'Lng': 82.7833,
#   'Max Temp': 70.23,
#   'Current Description': 'clear sky',
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 5.35,
#   'Country': 'IN'},
#  {'City': 'Yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 74.98,
#   'Current Description': 'broken clouds',
#   'Humidity': 88,
#   'Cloudiness': 54,
#   'Wind Speed': 2.37,
#   'Country': 'AU'},
#  {'City': 'Kinsale',
#   'Lat': 51.7075,
#   'Lng': -8.5306,
#   'Max Temp': 53.24,
#   'Current Description': 'broken clouds',
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'IE'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 52.68,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 8.41,
#   'Country': 'AU'},
#  {'City': 'Grand Baie',
#   'Lat': -20.0182,
#   'Lng': 57.5802,
#   'Max Temp': 75.67,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 89,
#   'Wind Speed': 1.99,
#   'Country': 'MU'},
#  {'City': 'Atar',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 94.32,
#   'Current Description': 'few clouds',
#   'Humidity': 10,
#   'Cloudiness': 20,
#   'Wind Speed': 12.59,
#   'Country': 'MR'},
#  {'City': 'Sabang',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 79.43,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 12.19,
#   'Country': 'ID'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 70.52,
#   'Current Description': 'scattered clouds',
#   'Humidity': 71,
#   'Cloudiness': 47,
#   'Wind Speed': 10.4,
#   'Country': 'MX'},
#  {'City': 'Bagaha',
#   'Lat': 27.1,
#   'Lng': 84.0833,
#   'Max Temp': 74.19,
#   'Current Description': 'clear sky',
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
# ...
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind Speed': 5.01,
#   'Country': 'US'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 78.96,
#   'Current Description': 'clear sky',
#   'Humidity': 75,
#   'Cloudiness': 9,
#   'Wind Speed': 9.69,
#   'Country': 'SO'},
#  {'City': 'Novyy Urengoy',
#   'Lat': 66.0833,
#   'Lng': 76.6333,
#   'Max Temp': 28.42,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 94,
#   'Wind Speed': 4.83,
#   'Country': 'RU'},
#  {'City': 'Kaoma',
#   'Lat': -14.7833,
#   'Lng': 24.8,
#   'Max Temp': 80.64,
#   'Current Description': 'broken clouds',
#   'Humidity': 38,
#   'Cloudiness': 73,
#   'Wind Speed': 1.21,
#   'Country': 'ZM'},
#  {'City': 'Krasnovishersk',
#   'Lat': 60.4078,
#   'Lng': 57.082,
#   'Max Temp': 44.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 9.64,
#   'Country': 'RU'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 70.36,
#   'Current Description': 'clear sky',
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'PT'},
#  {'City': 'Oyama',
#   'Lat': 36.3,
#   'Lng': 139.8,
#   'Max Temp': 54.59,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 97,
#   'Wind Speed': 2.1,
#   'Country': 'JP'},
#  {'City': 'Atakpame',
#   'Lat': 7.5333,
#   'Lng': 1.1333,
#   'Max Temp': 78.21,
#   'Current Description': 'light rain',
#   'Humidity': 80,
#   'Cloudiness': 69,
#   'Wind Speed': 3.02,
#   'Country': 'TG'},
#  {'City': 'Benton Harbor',
#   'Lat': 42.1167,
#   'Lng': -86.4542,
#   'Max Temp': 50.25,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Bayan',
#   'Lat': 46.0833,
#   'Lng': 127.4,
#   'Max Temp': 37.18,
#   'Current Description': 'clear sky',
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 7.09,
#   'Country': 'CN'},
#  {'City': 'Hatillo',
#   'Lat': 18.4863,
#   'Lng': -66.8254,
#   'Max Temp': 90.79,
#   'Current Description': 'clear sky',
#   'Humidity': 66,
#   'Cloudiness': 9,
#   'Wind Speed': 8.99,
#   'Country': 'PR'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 82.38,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Country': 'MX'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 81.05,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'IN'},
#  {'City': 'Jacmel',
#   'Lat': 18.2342,
#   'Lng': -72.5347,
#   'Max Temp': 87.64,
#   'Current Description': 'broken clouds',
#   'Humidity': 63,
#   'Cloudiness': 73,
#   'Wind Speed': 7.52,
#   'Country': 'HT'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': 23.61,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 8.23,
#   'Country': 'RU'},
#  {'City': 'Athabasca',
#   'Lat': 54.7169,
#   'Lng': -113.2854,
#   'Max Temp': 35.42,
#   'Current Description': 'broken clouds',
#   'Humidity': 51,
#   'Cloudiness': 69,
#   'Wind Speed': 15.82,
#   'Country': 'CA'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 76.03,
#   'Current Description': 'scattered clouds',
#   'Humidity': 87,
#   'Cloudiness': 26,
#   'Wind Speed': 14.18,
#   'Country': 'AU'},
#  {'City': 'Jovellanos',
#   'Lat': 22.8044,
#   'Lng': -81.1944,
#   'Max Temp': 84.54,
#   'Current Description': 'overcast clouds',
#   'Humidity': 67,
#   'Cloudiness': 96,
#   'Wind Speed': 5.53,
#   'Country': 'CU'},
#  {'City': 'Ubinskoye',
#   'Lat': 55.3068,
#   'Lng': 79.6802,
#   'Max Temp': 36.14,
#   'Current Description': 'scattered clouds',
#   'Humidity': 56,
#   'Cloudiness': 44,
#   'Wind Speed': 17.45,
#   'Country': 'RU'},
#  {'City': 'Skovorodino',
#   'Lat': 53.9833,
#   'Lng': 123.9167,
#   'Max Temp': 30.65,
#   'Current Description': 'scattered clouds',
#   'Humidity': 90,
#   'Cloudiness': 25,
#   'Wind Speed': 1.88,
#   'Country': 'RU'},
#  {'City': 'Krasni Okny',
#   'Lat': 47.5404,
#   'Lng': 29.46,
#   'Max Temp': 60.66,
#   'Current Description': 'scattered clouds',
#   'Humidity': 49,
#   'Cloudiness': 49,
#   'Wind Speed': 2.89,
#   'Country': 'UA'},
#  {'City': 'Sokoto',
#   'Lat': 13.0609,
#   'Lng': 5.239,
#   'Max Temp': 93.88,
#   'Current Description': 'scattered clouds',
#   'Humidity': 27,
#   'Cloudiness': 32,
#   'Wind Speed': 5.75,
#   'Country': 'NG'},
#  {'City': 'Tanout',
#   'Lat': 14.9709,
#   'Lng': 8.8879,
#   'Max Temp': 94.68,
#   'Current Description': 'broken clouds',
#   'Humidity': 19,
#   'Cloudiness': 77,
#   'Wind Speed': 13.15,
#   'Country': 'NE'},
#  {'City': 'Zharkent',
#   'Lat': 44.1628,
#   'Lng': 80,
#   'Max Temp': 38.57,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Country': 'KZ'},
#  {'City': 'Arica',
#   'Lat': -18.475,
#   'Lng': -70.3042,
#   'Max Temp': 67.55,
#   'Current Description': 'broken clouds',
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CL'},
#  {'City': 'Malatya',
#   'Lat': 38.5,
#   'Lng': 38,
#   'Max Temp': 50.05,
#   'Current Description': 'clear sky',
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'TR'},
#  {'City': 'Vagay',
#   'Lat': 57.9375,
#   'Lng': 69.0217,
#   'Max Temp': 36.82,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Country': 'RU'},
#  {'City': 'Killarney',
#   'Lat': 52.05,
#   'Lng': -9.5167,
#   'Max Temp': 53.65,
#   'Current Description': 'broken clouds',
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'IE'},
#  {'City': 'Sao Raimundo Nonato',
#   'Lat': -9.0153,
#   'Lng': -42.6994,
#   'Max Temp': 86.85,
#   'Current Description': 'moderate rain',
#   'Humidity': 51,
#   'Cloudiness': 96,
#   'Wind Speed': 0.29,
#   'Country': 'BR'},
#  {'City': 'San Ramon',
#   'Lat': 37.7799,
#   'Lng': -121.978,
#   'Max Temp': 58.14,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 54.59,
#   'Current Description': 'broken clouds',
#   'Humidity': 69,
#   'Cloudiness': 67,
#   'Wind Speed': 12.15,
#   'Country': 'RU'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 33.75,
#   'Current Description': 'overcast clouds',
#   'Humidity': 85,
#   'Cloudiness': 91,
#   'Wind Speed': 5.97,
#   'Country': 'RU'},
#  {'City': 'Dalvik',
#   'Lat': 65.9702,
#   'Lng': -18.5286,
#   'Max Temp': 35.53,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.53,
#   'Country': 'IS'},
#  {'City': 'Rovaniemi',
#   'Lat': 66.5,
#   'Lng': 25.7167,
#   'Max Temp': 29.61,
#   'Current Description': 'clear sky',
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Country': 'FI'},
#  {'City': 'Hailey',
#   'Lat': 43.5196,
#   'Lng': -114.3153,
#   'Max Temp': 48.06,
#   'Current Description': 'broken clouds',
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 78.55,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 88,
#   'Wind Speed': 10.16,
#   'Country': 'PG'},
#  {'City': 'Tarutyne',
#   'Lat': 46.1858,
#   'Lng': 29.1506,
#   'Max Temp': 61.7,
#   'Current Description': 'overcast clouds',
#   'Humidity': 49,
#   'Cloudiness': 99,
#   'Wind Speed': 8.28,
#   'Country': 'UA'},
#  {'City': 'Horn',
#   'Lat': 51.8715,
#   'Lng': 8.9451,
#   'Max Temp': 47.14,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 14.92,
#   'Country': 'DE'},
#  {'City': 'Mirnyy',
#   'Lat': 62.5353,
#   'Lng': 113.9611,
#   'Max Temp': 33.17,
#   'Current Description': 'overcast clouds',
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 8.84,
#   'Country': 'RU'},
#  {'City': 'Smidovich',
#   'Lat': 48.6,
#   'Lng': 133.8167,
#   'Max Temp': 33.87,
#   'Current Description': 'scattered clouds',
#   'Humidity': 70,
#   'Cloudiness': 32,
#   'Wind Speed': 8.16,
#   'Country': 'RU'},
#  {'City': 'Nabire',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 74.53,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.76,
#   'Country': 'ID'},
#  {'City': 'Boa Viagem',
#   'Lat': -5.1275,
#   'Lng': -39.7322,
#   'Max Temp': 95.23,
#   'Current Description': 'overcast clouds',
#   'Humidity': 32,
#   'Cloudiness': 85,
#   'Wind Speed': 6.76,
#   'Country': 'BR'},
#  {'City': 'Kaspiyskiy',
#   'Lat': 45.3929,
#   'Lng': 47.3707,
#   'Max Temp': 55.74,
#   'Current Description': 'clear sky',
#   'Humidity': 73,
#   'Cloudiness': 7,
#   'Wind Speed': 7.56,
#   'Country': 'RU'},
#  {'City': 'Tres Arroyos',
#   'Lat': -38.3739,
#   'Lng': -60.2798,
#   'Max Temp': 63.81,
#   'Current Description': 'overcast clouds',
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Country': 'AR'},
#  {'City': 'Pemberton',
#   'Lat': 50.3164,
#   'Lng': -122.8027,
#   'Max Temp': 51.49,
#   'Current Description': 'light rain',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Country': 'CA'},
#  {'City': 'Swellendam',
#   'Lat': -34.0226,
#   'Lng': 20.4417,
#   'Max Temp': 65.21,
#   'Current Description': 'overcast clouds',
#   'Humidity': 52,
#   'Cloudiness': 94,
#   'Wind Speed': 12.48,
#   'Country': 'ZA'},
#  {'City': 'Kemijarvi',
#   'Lat': 66.7131,
#   'Lng': 27.4306,
#   'Max Temp': 28.24,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 14.94,
#   'Country': 'FI'},
#  {'City': 'Hegang',
#   'Lat': 47.4,
#   'Lng': 130.3667,
#   'Max Temp': 35.38,
#   'Current Description': 'clear sky',
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 5.59,
#   'Country': 'CN'},
#  {'City': 'Holland',
#   'Lat': 42.7875,
#   'Lng': -86.1089,
#   'Max Temp': 52.65,
#   'Current Description': 'broken clouds',
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Los Lunas',
#   'Lat': 34.8062,
#   'Lng': -106.7334,
#   'Max Temp': 71.87,
#   'Current Description': 'clear sky',
#   'Humidity': 18,
#   'Cloudiness': 9,
#   'Wind Speed': 3.4,
#   'Country': 'US'},
#  {'City': 'Cabo Rojo',
#   'Lat': 18.0866,
#   'Lng': -67.1457,
#   'Max Temp': 90.68,
#   'Current Description': 'scattered clouds',
#   'Humidity': 59,
#   'Cloudiness': 46,
#   'Wind Speed': 5.99,
#   'Country': 'PR'},
#  {'City': 'Sobolevo',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 43.75,
#   'Current Description': 'scattered clouds',
#   'Humidity': 70,
#   'Cloudiness': 47,
#   'Wind Speed': 15.17,
#   'Country': 'RU'},
#  {'City': 'San Jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 59.27,
#   'Current Description': 'mist',
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Carbonia',
#   'Lat': 39.1672,
#   'Lng': 8.5222,
#   'Max Temp': 72.01,
#   'Current Description': 'broken clouds',
#   'Humidity': 70,
#   'Cloudiness': 66,
#   'Wind Speed': 6.35,
#   'Country': 'IT'},
#  {'City': 'Kiama',
#   'Lat': -34.6833,
#   'Lng': 150.8667,
#   'Max Temp': 62.58,
#   'Current Description': 'clear sky',
#   'Humidity': 89,
#   'Cloudiness': 5,
#   'Wind Speed': 8.99,
#   'Country': 'AU'},
#  {'City': 'Kautokeino',
#   'Lat': 69.0125,
#   'Lng': 23.0412,
#   'Max Temp': 17.67,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 10.45,
#   'Country': 'NO'},
#  {'City': 'Bayeux',
#   'Lat': -7.125,
#   'Lng': -34.9322,
#   'Max Temp': 88.43,
#   'Current Description': 'broken clouds',
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'BR'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 80.19,
#   'Current Description': 'scattered clouds',
#   'Humidity': 78,
#   'Cloudiness': 45,
#   'Wind Speed': 14.25,
#   'Country': 'SO'},
#  {'City': 'Rongcheng',
#   'Lat': 30.634,
#   'Lng': 117.8517,
#   'Max Temp': 52.5,
#   'Current Description': 'light rain',
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 3.02,
#   'Country': 'CN'},
#  {'City': 'Calvinia',
#   'Lat': -31.4707,
#   'Lng': 19.776,
#   'Max Temp': 55.35,
#   'Current Description': 'overcast clouds',
#   'Humidity': 59,
#   'Cloudiness': 96,
#   'Wind Speed': 19.04,
#   'Country': 'ZA'},
#  {'City': 'Togur',
#   'Lat': 58.3631,
#   'Lng': 82.8265,
#   'Max Temp': 35.19,
#   'Current Description': 'overcast clouds',
#   'Humidity': 65,
#   'Cloudiness': 97,
#   'Wind Speed': 14.76,
#   'Country': 'RU'},
#  {'City': 'Kelvington',
#   'Lat': 52.1667,
#   'Lng': -103.5343,
#   'Max Temp': 29.86,
#   'Current Description': 'clear sky',
#   'Humidity': 57,
#   'Cloudiness': 5,
#   'Wind Speed': 12.73,
#   'Country': 'CA'},
#  {'City': 'Sar-E Pul',
#   'Lat': 35.8333,
#   'Lng': 66.1667,
#   'Max Temp': 36.12,
#   'Current Description': 'scattered clouds',
#   'Humidity': 80,
#   'Cloudiness': 37,
#   'Wind Speed': 1.5,
#   'Country': 'AF'},
#  {'City': 'Paracuru',
#   'Lat': -3.41,
#   'Lng': -39.0306,
#   'Max Temp': 87.82,
#   'Current Description': 'broken clouds',
#   'Humidity': 55,
#   'Cloudiness': 69,
#   'Wind Speed': 14.74,
#   'Country': 'BR'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 38.1,
#   'Current Description': 'broken clouds',
#   'Humidity': 65,
#   'Cloudiness': 80,
#   'Wind Speed': 2.89,
#   'Country': 'CN'},
#  {'City': 'Rudnichnyy',
#   'Lat': 59.617,
#   'Lng': 52.4703,
#   'Max Temp': 46.81,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 12.88,
#   'Country': 'RU'},
#  {'City': 'Wanganui',
#   'Lat': -39.9333,
#   'Lng': 175.05,
#   'Max Temp': 43.74,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'NZ'},
#  {'City': 'Cap-Haitien',
#   'Lat': 19.7578,
#   'Lng': -72.2042,
#   'Max Temp': 83.25,
#   'Current Description': 'broken clouds',
#   'Humidity': 66,
#   'Cloudiness': 66,
#   'Wind Speed': 8.81,
#   'Country': 'HT'},
#  {'City': 'Iroquois Falls',
#   'Lat': 48.7669,
#   'Lng': -80.6831,
#   'Max Temp': 33.94,
#   'Current Description': 'overcast clouds',
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 7.45,
#   'Country': 'CA'},
#  {'City': 'Khash',
#   'Lat': 28.2211,
#   'Lng': 61.2158,
#   'Max Temp': 58.41,
#   'Current Description': 'clear sky',
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 4.34,
#   'Country': 'IR'},
#  {'City': 'Izmaylovo',
#   'Lat': 53.7211,
#   'Lng': 47.2458,
#   'Max Temp': 51.93,
#   'Current Description': 'overcast clouds',
#   'Humidity': 75,
#   'Cloudiness': 87,
#   'Wind Speed': 16.33,
#   'Country': 'RU'},
#  {'City': 'Vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': 29.08,
#   'Current Description': 'light snow',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Country': 'RU'},
#  {'City': 'Ploemeur',
#   'Lat': 47.7333,
#   'Lng': -3.4333,
#   'Max Temp': 59.86,
#   'Current Description': 'few clouds',
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'FR'},
#  {'City': 'Rio Claro',
#   'Lat': -22.4114,
#   'Lng': -47.5614,
#   'Max Temp': 82.22,
#   'Current Description': 'clear sky',
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 3.15,
#   'Country': 'BR'},
#  {'City': 'Paraiso',
#   'Lat': 9.8383,
#   'Lng': -83.8656,
#   'Max Temp': 79.88,
#   'Current Description': 'overcast clouds',
#   'Humidity': 54,
#   'Cloudiness': 92,
#   'Wind Speed': 3.8,
#   'Country': 'CR'},
#  {'City': 'Bhabua',
#   'Lat': 25.05,
#   'Lng': 83.6167,
#   'Max Temp': 70.95,
#   'Current Description': 'clear sky',
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 3.38,
#   'Country': 'IN'},
#  {'City': 'Nara',
#   'Lat': 34.6851,
#   'Lng': 135.8049,
#   'Max Temp': 60.08,
#   'Current Description': 'broken clouds',
#   'Humidity': 51,
#   'Cloudiness': 61,
#   'Wind Speed': 8.86,
#   'Country': 'JP'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -4.16,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.7,
#   'Country': 'RU'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 59.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 19.6,
#   'Country': 'NZ'},
#  {'City': 'Wanning',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 71.73,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 91,
#   'Wind Speed': 15.84,
#   'Country': 'CN'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp Current Description  \
# 0           Miandrivazo -19.5167   45.4667     76.28          few clouds
# 1                Barrow  71.2906 -156.7887     26.62     overcast clouds
# 2             Busselton -33.6500  115.3333     50.09           clear sky
# 3  Vila Franca Do Campo  37.7167  -25.4333     70.21           clear sky
# 4                 Kapaa  22.0752 -159.3190     75.52          light rain
# 5                 Vaini -21.2000 -175.2000     69.96    scattered clouds
# 6             Roebourne -20.7833  117.1333     81.52          few clouds
# 7                  Asau  46.4333   26.4000     60.40     overcast clouds
# 8                 Korla  41.7597   86.1469     59.40     overcast clouds
# 9               Ushuaia -54.8000  -68.3000     49.66    scattered clouds
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        56          17        8.48      MG
# 1        93          90        0.00      US
# 2        74           7        7.36      AU
# 3        62           8        5.82      PT
# 4        93          40        9.22      US
# 5        88          40        9.22      TO
# 6        32          20        7.09      AU
# 7        61         100        5.03      RO
# 8        22          95       14.72      CN
# 9        50          40       24.16      AR

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
