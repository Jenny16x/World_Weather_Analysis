# %%
import random
from citipy import citipy
import numpy as np
from config import weather_api_key
import requests
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# atuona pf
# butaritari ki
# rikitea pf
# pontal do parana br
# westport ie
# capinopolis br
# kaitangata nz
# dubbo au
# port alfred za
# coquimbo cl
# tuktoyaktuk ca
# galich ru
# qaanaaq gl
# rikitea pf
# sao jose da coroa grande br
# lebu cl
# lompoc us
# hilo us
# inderborskiy kz
# arraial do cabo br
# cape town za
# yellowknife ca
# dingle ie
# namibe ao
# celestun mx
# ushuaia ar
# east london za
# butaritari ki
# jamestown sh
# westport ie
# constitucion mx
# saint-francois gp
# punta arenas cl
# butaritari ki
# mataura pf
# imeni poliny osipenko ru
# vila velha br
# kirgiz-miyaki ru
# samusu ws
# meadow lake ca
# coolidge us
# saint george bm
# bandarbeyla so
# butaritari ki
# berlevag no
# castro cl
# ilulissat gl
# buraydah sa
# hilo us
# broome au
# busselton au
# nikolskoye ru
# jiddah sa
# mataura pf
# punta arenas cl
# punta arenas cl
# rikitea pf
# vardo no
# attawapiskat ca
# bambous virieux mu
# hobart au
# kitimat ca
# boa vista br
# vaini to
# mys shmidta ru
# castro cl
# tuktoyaktuk ca
# castro cl
# ushuaia ar
# posse br
# madang pg
# rikitea pf
# lebu cl
# punta arenas cl
# saint-philippe re
# mahon es
# mar del plata ar
# klaksvik fo
# bluff nz
# saldanha za
# saldanha za
# skreia no
# arraial do cabo br
# boden se
# lolua tv
# mrakovo ru
# new norfolk au
# ushuaia ar
# nizhneyansk ru
# luderitz na
# punta arenas cl
# meyungs pw
# victoria us
# hilo us
# hilo us
# qaanaaq gl
# gangotri in
# kruisfontein za
# adamas gr
# tuktoyaktuk ca
# luderitz na
# bilibino ru
# halifax ca
# pitimbu br
# berlevag no
# quelimane mz
# taolanaro mg
# tsihombe mg
# altay cn
# mecca sa
# cabo san lucas mx
# hobart au
# goderich sl
# thompson ca
# tasiilaq gl
# nikolskoye ru
# mataura pf
# nhulunbuy au
# hithadhoo mv
# cockburn town tc
# belushya guba ru
# barentsburg sj
# san cristobal ec
# zhigansk ru
# kapaa us
# taolanaro mg
# semey kz
# tumannyy ru
# andenes no
# atuona pf
# kushiro jp
# bluff nz
# cabo san lucas mx
# albany au
# ushuaia ar
# andenes no
# new norfolk au
# waingapu id
# norman wells ca
# da nang vn
# acapulco mx
# tepelene al
# navalmoral de la mata es
# vejalpur in
# saint-georges gf
# coihaique cl
# ambatofinandrahana mg
# cape town za
# sao joao da barra br
# kupang id
# honningsvag no
# busselton au
# andenes no
# vaini to
# jamestown sh
# kodiak us
# ushuaia ar
# kodiak us
# marondera zw
# kapaa us
# ushuaia ar
# biankouma ci
# torbay ca
# touros br
# verkhoyansk ru
# vaini to
# rikitea pf
# puerto escondido mx
# tocopilla cl
# ushuaia ar
# tabialan ph
# kapaa us
# punta arenas cl
# nanortalik gl
# lebu cl
# kurumkan ru
# vaitupu wf
# arman ru
# butaritari ki
# nikolskoye ru
# pingliang cn
# bonthe sl
# rikitea pf
# vaitupu wf
# balakhta ru
# belushya guba ru
# pacifica us
# busselton au
# sambava mg
# ushuaia ar
# ushuaia ar
# namibe ao
# rikitea pf
# petrolandia br
# basoko cd
# hithadhoo mv
# jamestown sh
# mataura pf
# ribeira grande pt
# rikitea pf
# mataura pf
# porbandar in
# salekhard ru
# qaanaaq gl
# barentsburg sj
# albany au
# hilo us
# mataura pf
# dole fr
# arraial do cabo br
# yellowknife ca
# vaini to
# sao bento do sul br
# ribeira grande pt
# port alfred za
# ribeira grande pt
# chapais ca
# da lat vn
# mataura pf
# ponta do sol cv
# itaqui br
# mataura pf
# lebu cl
# vaini to
# bredasdorp za
# vaini to
# taolanaro mg
# tomatlan mx
# beringovskiy ru
# vaini to
# corn island ni
# lishui cn
# punta arenas cl
# constitucion cl
# verkhnevilyuysk ru
# saint-joseph re
# busselton au
# tumannyy ru
# saint-pierre pm
# blythe us
# georgetown sh
# albany au
# chokurdakh ru
# ginda er
# belyy yar ru
# port alfred za
# princeton ca
# mys shmidta ru
# kochki ru
# bengkulu id
# faanui pf
# kloulklubed pw
# russkiy aktash ru
# najran sa
# sinnamary gf
# qandala so
# nizhneyansk ru
# faanui pf
# taolanaro mg
# ossora ru
# aloleng ph
# chokurdakh ru
# placido de castro br
# temaraia ki
# punta arenas cl
# puerto ayora ec
# vaini to
# viesca mx
# half moon bay us
# tripoli ly
# pachora in
# saleaula ws
# maumere id
# taolanaro mg
# rikitea pf
# taolanaro mg
# arraial do cabo br
# fortuna us
# bluff nz
# mataura pf
# albany au
# antofagasta cl
# yellowknife ca
# biak id
# coahuayana mx
# comodoro rivadavia ar
# sitka us
# puerto ayora ec
# port alfred za
# meadow lake ca
# albany au
# atambua id
# tiksi ru
# astoria us
# port alfred za
# gardan diwal af
# ushuaia ar
# hermanus za
# antalaha mg
# busselton au
# devils lake us
# punta arenas cl
# vila do maio cv
# bitung id
# vaini to
# udachnyy ru
# rikitea pf
# faanui pf
# sayyan ye
# new norfolk au
# atuona pf
# ilulissat gl
# mataura pf
# tuktoyaktuk ca
# albany au
# ranong th
# hermanus za
# torbay ca
# saskylakh ru
# takoradi gh
# bressuire fr
# esperance au
# avarua ck
# butaritari ki
# banda aceh id
# carberry ca
# cape town za
# morant bay jm
# amderma ru
# mys shmidta ru
# tolyatti ru
# san cristobal ec
# elizabeth city us
# ushuaia ar
# ilulissat gl
# punta arenas cl
# torbay ca
# thompson ca
# barrow us
# codrington ag
# kapaa us
# barrow us
# mataura pf
# dikson ru
# surt ly
# airai pw
# isangel vu
# bengkulu id
# taolanaro mg
# busselton au
# cape town za
# pacific grove us
# qasigiannguit gl
# hambantota lk
# esperance au
# kapaa us
# albany au
# busselton au
# komsomolskiy ru
# broome au
# orlik ru
# burkhala ru
# mataura pf
# upernavik gl
# nanortalik gl
# victoria sc
# vaitupu wf
# dinsor so
# yerbogachen ru
# busselton au
# hami cn
# rikitea pf
# beloha mg
# barentsburg sj
# okhotsk ru
# vaini to
# east london za
# ust-ishim ru
# hilo us
# bambous virieux mu
# atuona pf
# sperkhias gr
# hovd mn
# beloha mg
# udachnyy ru
# illoqqortoormiut gl
# encheng cn
# neepawa ca
# kuche cn
# rikitea pf
# bethel us
# tawkar sd
# uwayl sd
# puerto ayacucho ve
# klaksvik fo
# carpentras fr
# busselton au
# mataura pf
# tasiilaq gl
# mataura pf
# shar kz
# da nang vn
# flinders au
# petropavlovsk-kamchatskiy ru
# gimli ca
# vaini to
# oistins bb
# lahad datu my
# vaini to
# alyangula au
# port alfred za
# mar del plata ar
# cherskiy ru
# tsihombe mg
# yarmouth ca
# quatre cocos mu
# varhaug no
# belushya guba ru
# roma au
# illoqqortoormiut gl
# kaitangata nz
# castro cl
# atuona pf
# kapaa us
# lusambo cd
# nata bw
# falealupo ws
# ponta do sol cv
# saint-georges gf
# souillac mu
# arraial do cabo br
# shimoda jp
# port alfred za
# cape town za
# qaanaaq gl
# port lincoln au
# basco ph
# ushuaia ar
# mazatlan mx
# punta arenas cl
# puerto ayora ec
# kavieng pg
# illoqqortoormiut gl
# mayumba ga
# kapaa us
# atuona pf
# avarua ck
# vaini to
# saldanha za
# hobart au
# dingle ie
# gawler au
# san quintin mx
# port hedland au
# georgetown sh
# rocha uy
# natitingou bj
# sakaiminato jp
# nishihara jp
# vilhena br
# nikolskoye ru
# acapulco mx
# luderitz na
# college us
# illoqqortoormiut gl
# hovd mn
# yumen cn
# broken hill au
# east london za
# cairns au
# shimoda jp
# hithadhoo mv
# baykit ru
# mayo ca
# east london za
# hasaki jp
# saint-philippe re
# mataura pf
# avarua ck
# bolungarvik is
# macaboboni ph
# barrow us
# mataura pf
# ushuaia ar
# vaini to
# geraldton au
# deputatskiy ru
# palabuhanratu id
# aklavik ca
# hobart au
# vaini to
# tuktoyaktuk ca
# saskylakh ru
# nazare pt
# namibe ao
# cabedelo br
# samusu ws
# barrow us
# ushuaia ar
# kamenka ru
# chuy uy
# new norfolk au
# rikitea pf
# belushya guba ru
# pacific grove us
# klaksvik fo
# mayo ca
# tromso no
# faanui pf
# lanzhou cn
# sorvag fo
# hobart au
# hvammstangi is
# ushuaia ar
# zhanaozen kz
# macea ro
# east london za
# nanortalik gl
# qaanaaq gl
# collie au
# tasiilaq gl
# ushuaia ar
# georgetown sh
# albany au
# bethel us
# ambon id
# punta arenas cl
# sentyabrskiy ru
# atuona pf
# cape town za
# rio gallegos ar
# cape town za
# ushuaia ar
# santa cruz cr
# nome us
# port hardy ca
# moron mn
# port alfred za
# albany au
# san juan de uraba co
# ribas do rio pardo br
# maniitsoq gl
# mataura pf
# doha kw
# corralillo cu
# tasiilaq gl
# kita ml
# leh in
# baykit ru
# khatanga ru
# hermanus za
# yellowknife ca
# busselton au
# albany au
# rikitea pf
# guerrero negro mx
# saint-georges gf
# albany au
# lasa cn
# hithadhoo mv
# meulaboh id
# qaqortoq gl
# taolanaro mg
# rizhao cn
# dikson ru
# yellowknife ca
# turinsk ru
# amderma ru
# keta gh
# bargal so
# bluff nz
# punta arenas cl
# kodiak us
# dikson ru
# mount gambier au
# busselton au
# attawapiskat ca
# trairi br
# kijang id
# saint anthony ca
# rikitea pf
# ancud cl
# tambovka ru
# rikitea pf
# mataura pf
# muriwai beach nz
# new norfolk au
# guatire ve
# faanui pf
# milkovo ru
# rikitea pf
# solsvik no
# rikitea pf
# port elizabeth za
# hermanus za
# lima duarte br
# yellowknife ca
# illoqqortoormiut gl
# rikitea pf
# portland au
# ushuaia ar
# baykit ru
# taolanaro mg
# lakatoro vu
# hermanus za
# troy us
# pacific grove us
# praia da vitoria pt
# gweta bw
# jamestown sh
# olinda br
# yellowknife ca
# tiksi ru
# dwarka in
# qaanaaq gl
# albany au
# qaanaaq gl
# roald no
# samalaeulu ws
# airai pw
# avarua ck
# rikitea pf
# terrace bay ca
# bredasdorp za
# xining cn
# san patricio mx
# qaanaaq gl
# busselton au
# alice springs au
# busselton au
# nanortalik gl
# toliary mg
# saint george bm
# bredasdorp za
# novyy karachay ru
# hanumangarh in
# rikitea pf
# luderitz na
# fallon us
# kurilsk ru
# rikitea pf
# chicama pe
# lavrentiya ru
# conceicao da barra br
# punta arenas cl
# dikson ru
# rikitea pf
# aflu dz
# nemuro jp
# kruisfontein za
# vaini to
# provideniya ru
# saint-philippe re
# wakkanai jp
# hilo us
# anadyr ru
# anadyr ru
# chokurdakh ru
# belmonte br
# newcastleton gb
# touros br
# bathsheba bb
# hobart au
# athabasca ca
# chuy uy
# hobart au
# reitz za
# hinton ca
# kamenskoye ru
# samfya zm
# mataura pf
# ihosy mg
# port elizabeth za
# malakal sd
# touros br
# chapais ca
# alice springs au
# vaini to
# wasilla us
# jalu ly
# kashary ru
# lengshuitan cn
# coquimbo cl
# palabuhanratu id
# upernavik gl
# tsihombe mg
# ankara tr
# sambava mg
# araouane ml
# vaini to
# victoria sc
# port alfred za
# sakakah sa
# victoria sc
# wattegama lk
# katsuura jp
# asau tv
# kathu za
# arraial do cabo br
# mortka ru
# geraldton au
# hithadhoo mv
# maniwaki ca
# pacific grove us
# rikitea pf
# airai pw
# hermanus za
# henties bay na
# yazman pk
# new norfolk au
# qinnan cn
# albany au
# flinders au
# albany au
# tessalit ml
# port alfred za
# poum nc
# hobart au
# cabo san lucas mx
# vao nc
# castro cl
# bluff nz
# adrar dz
# mar del plata ar
# lavrentiya ru
# rikitea pf
# tsihombe mg
# codrington ag
# east london za
# cidreira br
# guadalajara es
# garowe so
# rikitea pf
# puerto ayora ec
# qaanaaq gl
# padang id
# castro cl
# tuktoyaktuk ca
# cherskiy ru
# port lincoln au
# busselton au
# mar del plata ar
# attawapiskat ca
# punta arenas cl
# najran sa
# hermanus za
# evensk ru
# olafsvik is
# upernavik gl
# hithadhoo mv
# cerrito py
# kaitangata nz
# hilo us
# deputatskiy ru
# albany au
# homer us
# ribeira grande pt
# diego de almagro cl
# severo-kurilsk ru
# srivardhan in
# puerto escondido mx
# qaanaaq gl
# hermanus za
# naze jp
# new norfolk au
# rikitea pf
# vaitupu wf
# great falls us
# tasiilaq gl
# tuktoyaktuk ca
# rikitea pf
# ushuaia ar
# alice springs au
# cairns au
# nikolskoye ru
# hobart au
# bluff nz
# bredasdorp za
# nizhneyansk ru
# lolua tv
# busselton au
# yellowknife ca
# butaritari ki
# hay river ca
# belmonte br
# ocampo mx
# ust-kuyga ru
# norman wells ca
# sentyabrskiy ru
# dingle ie
# narsaq gl
# aswan eg
# busselton au
# yerbogachen ru
# bonito br
# patos de minas br
# rocha uy
# hithadhoo mv
# bluff nz
# kapaa us
# puerto ayora ec
# punta arenas cl
# ushuaia ar
# leningradskiy ru
# fairbanks us
# komsomolskiy ru
# albany au
# new norfolk au
# izumo jp
# mataura pf
# sitka us
# chinsali zm
# mys shmidta ru
# kollam in
# umzimvubu za
# severnoye ru
# albany au
# shimoda jp
# qaanaaq gl
# katsuura jp
# severo-kurilsk ru
# busselton au
# korla cn
# punta arenas cl
# bluff nz
# khatanga ru
# provideniya ru
# fairbanks us
# mataura pf
# port alfred za
# arraial do cabo br
# albany au
# kaitangata nz
# hithadhoo mv
# bluff nz
# hithadhoo mv
# meulaboh id
# busselton au
# shakawe bw

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 761

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + city.replace(" ", "+")
city_weather = requests.get(city_url).json()
print(city_weather)
# Out:
# {'coord': {'lon': 21.85, 'lat': -18.3667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 88.2, 'feels_like': 86.31, 'temp_min': 88.2, 'temp_max': 88.2, 'pressure': 1007, 'humidity': 32, 'sea_level': 1007, 'grnd_level': 901}, 'visibility': 10000, 'wind': {'speed': 6.62, 'deg': 309, 'gust': 10.87}, 'clouds': {'all': 63}, 'dt': 1634919949, 'sys': {'country': 'BW', 'sunrise': 1634875104, 'sunset': 1634920525}, 'timezone': 7200, 'id': 933077, 'name': 'Shakawe', 'cod': 200}

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | pontal do parana
# Processing Record 5 of Set 1 | westport
# Processing Record 6 of Set 1 | capinopolis
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | dubbo
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | galich
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | sao jose da coroa grande
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | dingle
# Processing Record 23 of Set 1 | namibe
# Processing Record 24 of Set 1 | celestun
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | constitucion
# Processing Record 29 of Set 1 | saint-francois
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | imeni poliny osipenko
# Processing Record 33 of Set 1 | vila velha
# Processing Record 34 of Set 1 | kirgiz-miyaki
# Processing Record 35 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 1 | meadow lake
# Processing Record 37 of Set 1 | coolidge
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | bandarbeyla
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | buraydah
# Processing Record 44 of Set 1 | broome
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 1 | vardo
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | kitimat
# Processing Record 3 of Set 2 | boa vista
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | posse
# Processing Record 7 of Set 2 | madang
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | mahon
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | klaksvik
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | skreia
# Processing Record 15 of Set 2 | boden
# Processing Record 16 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 2 | mrakovo
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 24 of Set 2 | kruisfontein
# Processing Record 25 of Set 2 | adamas
# Processing Record 26 of Set 2 | bilibino
# Processing Record 27 of Set 2 | halifax
# Processing Record 28 of Set 2 | pitimbu
# Processing Record 29 of Set 2 | quelimane
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 2 | altay
# Processing Record 33 of Set 2 | mecca
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | goderich
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | nhulunbuy
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | cockburn town
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | san cristobal
# Processing Record 44 of Set 2 | zhigansk
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | semey
# Processing Record 47 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 2 | andenes
# Processing Record 49 of Set 2 | kushiro
# Processing Record 50 of Set 2 | albany
# Processing Record 1 of Set 3 | waingapu
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | da nang
# Processing Record 4 of Set 3 | acapulco
# Processing Record 5 of Set 3 | tepelene
# Processing Record 6 of Set 3 | navalmoral de la mata
# Processing Record 7 of Set 3 | vejalpur
# Processing Record 8 of Set 3 | saint-georges
# Processing Record 9 of Set 3 | coihaique
# Processing Record 10 of Set 3 | ambatofinandrahana
# Processing Record 11 of Set 3 | sao joao da barra
# Processing Record 12 of Set 3 | kupang
# Processing Record 13 of Set 3 | honningsvag
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | marondera
# Processing Record 16 of Set 3 | biankouma
# Processing Record 17 of Set 3 | torbay
# Processing Record 18 of Set 3 | touros
# Processing Record 19 of Set 3 | verkhoyansk
# Processing Record 20 of Set 3 | puerto escondido
# Processing Record 21 of Set 3 | tocopilla
# Processing Record 22 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | kurumkan
# Processing Record 25 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 3 | arman
# Processing Record 27 of Set 3 | pingliang
# Processing Record 28 of Set 3 | bonthe
# Processing Record 29 of Set 3 | balakhta
# Processing Record 30 of Set 3 | pacifica
# Processing Record 31 of Set 3 | sambava
# Processing Record 32 of Set 3 | petrolandia
# City not found. Skipping...
# Processing Record 33 of Set 3 | basoko
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | porbandar
# Processing Record 36 of Set 3 | salekhard
# Processing Record 37 of Set 3 | dole
# Processing Record 38 of Set 3 | sao bento do sul
# Processing Record 39 of Set 3 | chapais
# Processing Record 40 of Set 3 | da lat
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | itaqui
# Processing Record 43 of Set 3 | bredasdorp
# Processing Record 44 of Set 3 | tomatlan
# Processing Record 45 of Set 3 | beringovskiy
# Processing Record 46 of Set 3 | corn island
# Processing Record 47 of Set 3 | lishui
# Processing Record 48 of Set 3 | verkhnevilyuysk
# Processing Record 49 of Set 3 | saint-joseph
# Processing Record 50 of Set 3 | saint-pierre
# Processing Record 1 of Set 4 | blythe
# Processing Record 2 of Set 4 | georgetown
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | ginda
# Processing Record 5 of Set 4 | belyy yar
# Processing Record 6 of Set 4 | princeton
# Processing Record 7 of Set 4 | kochki
# Processing Record 8 of Set 4 | bengkulu
# Processing Record 9 of Set 4 | faanui
# Processing Record 10 of Set 4 | kloulklubed
# Processing Record 11 of Set 4 | russkiy aktash
# Processing Record 12 of Set 4 | najran
# Processing Record 13 of Set 4 | sinnamary
# Processing Record 14 of Set 4 | qandala
# Processing Record 15 of Set 4 | ossora
# Processing Record 16 of Set 4 | aloleng
# Processing Record 17 of Set 4 | placido de castro
# Processing Record 18 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | viesca
# Processing Record 21 of Set 4 | half moon bay
# Processing Record 22 of Set 4 | tripoli
# Processing Record 23 of Set 4 | pachora
# Processing Record 24 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 4 | maumere
# Processing Record 26 of Set 4 | fortuna
# Processing Record 27 of Set 4 | antofagasta
# Processing Record 28 of Set 4 | biak
# Processing Record 29 of Set 4 | coahuayana
# Processing Record 30 of Set 4 | comodoro rivadavia
# Processing Record 31 of Set 4 | sitka
# Processing Record 32 of Set 4 | atambua
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | astoria
# Processing Record 35 of Set 4 | gardan diwal
# City not found. Skipping...
# Processing Record 36 of Set 4 | hermanus
# Processing Record 37 of Set 4 | antalaha
# Processing Record 38 of Set 4 | devils lake
# Processing Record 39 of Set 4 | vila do maio
# Processing Record 40 of Set 4 | bitung
# Processing Record 41 of Set 4 | udachnyy
# Processing Record 42 of Set 4 | sayyan
# Processing Record 43 of Set 4 | ranong
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | takoradi
# Processing Record 46 of Set 4 | bressuire
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | avarua
# Processing Record 49 of Set 4 | banda aceh
# Processing Record 50 of Set 4 | carberry
# Processing Record 1 of Set 5 | morant bay
# Processing Record 2 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 5 | tolyatti
# Processing Record 4 of Set 5 | elizabeth city
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | codrington
# Processing Record 7 of Set 5 | dikson
# Processing Record 8 of Set 5 | surt
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | isangel
# Processing Record 11 of Set 5 | pacific grove
# Processing Record 12 of Set 5 | qasigiannguit
# Processing Record 13 of Set 5 | hambantota
# Processing Record 14 of Set 5 | komsomolskiy
# Processing Record 15 of Set 5 | orlik
# Processing Record 16 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 19 of Set 5 | yerbogachen
# Processing Record 20 of Set 5 | hami
# Processing Record 21 of Set 5 | beloha
# Processing Record 22 of Set 5 | okhotsk
# Processing Record 23 of Set 5 | ust-ishim
# Processing Record 24 of Set 5 | yulara
# Processing Record 25 of Set 5 | elat
# Processing Record 26 of Set 5 | ostrovnoy
# Processing Record 27 of Set 5 | provideniya
# Processing Record 28 of Set 5 | cumra
# Processing Record 29 of Set 5 | micomeseng
# Processing Record 30 of Set 5 | sydney
# Processing Record 31 of Set 5 | khani
# Processing Record 32 of Set 5 | hasaki
# Processing Record 33 of Set 5 | koster
# Processing Record 34 of Set 5 | isiro
# Processing Record 35 of Set 5 | miraflores
# Processing Record 36 of Set 5 | te anau
# Processing Record 37 of Set 5 | krasnoselkup
# Processing Record 38 of Set 5 | bathsheba
# Processing Record 39 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 5 | aviles
# Processing Record 41 of Set 5 | the pas
# Processing Record 42 of Set 5 | broken hill
# Processing Record 43 of Set 5 | luganville
# Processing Record 44 of Set 5 | gurupa
# Processing Record 45 of Set 5 | sidi qasim
# City not found. Skipping...
# Processing Record 46 of Set 5 | lagoa
# Processing Record 47 of Set 5 | buala
# Processing Record 48 of Set 5 | tatawin
# Processing Record 49 of Set 5 | tautira
# Processing Record 50 of Set 5 | begunitsy
# Processing Record 1 of Set 6 | rocha
# Processing Record 2 of Set 6 | sao filipe
# Processing Record 3 of Set 6 | xining
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | port hardy
# Processing Record 6 of Set 6 | makakilo city
# Processing Record 7 of Set 6 | sechura
# Processing Record 8 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 6 | lasa
# Processing Record 10 of Set 6 | san ramon de la nueva oran
# Processing Record 11 of Set 6 | gigmoto
# Processing Record 12 of Set 6 | sorata
# Processing Record 13 of Set 6 | port elizabeth
# Processing Record 14 of Set 6 | straumen
# Processing Record 15 of Set 6 | nyurba
# Processing Record 16 of Set 6 | cherskiy
# Processing Record 17 of Set 6 | charters towers
# Processing Record 18 of Set 6 | aksarka
# Processing Record 19 of Set 6 | bose
# Processing Record 20 of Set 6 | mudgee
# Processing Record 21 of Set 6 | nokaneng
# Processing Record 22 of Set 6 | novouzensk
# Processing Record 23 of Set 6 | pouebo
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | iralaya
# Processing Record 26 of Set 6 | mount gambier
# Processing Record 27 of Set 6 | la ronge
# Processing Record 28 of Set 6 | eenhana
# Processing Record 29 of Set 6 | mao
# Processing Record 30 of Set 6 | cocobeach
# Processing Record 31 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 6 | darovskoy
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | havre-saint-pierre
# Processing Record 35 of Set 6 | mount isa
# Processing Record 36 of Set 6 | bubaque
# Processing Record 37 of Set 6 | belaya gora
# Processing Record 38 of Set 6 | haines junction
# Processing Record 39 of Set 6 | walvis bay
# Processing Record 40 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 6 | lebedyn
# Processing Record 42 of Set 6 | qaqortoq
# Processing Record 43 of Set 6 | souillac
# Processing Record 44 of Set 6 | pimentel
# Processing Record 45 of Set 6 | killybegs
# Processing Record 46 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 6 | bangui
# Processing Record 48 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 6 | olinda
# Processing Record 50 of Set 6 | senno
# Processing Record 1 of Set 7 | pevek
# Processing Record 2 of Set 7 | chuy
# Processing Record 3 of Set 7 | roebourne
# Processing Record 4 of Set 7 | kokstad
# Processing Record 5 of Set 7 | sturgeon falls
# Processing Record 6 of Set 7 | nova olinda do norte
# Processing Record 7 of Set 7 | baherden
# Processing Record 8 of Set 7 | ludvika
# Processing Record 9 of Set 7 | karratha
# Processing Record 10 of Set 7 | langsa
# Processing Record 11 of Set 7 | naze
# Processing Record 12 of Set 7 | longyearbyen
# Processing Record 13 of Set 7 | derzhavinsk
# Processing Record 14 of Set 7 | emerald
# Processing Record 15 of Set 7 | yeppoon
# Processing Record 16 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 7 | sijunjung
# Processing Record 18 of Set 7 | pitea
# Processing Record 19 of Set 7 | xichang
# Processing Record 20 of Set 7 | nemuro
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | narsaq
# Processing Record 23 of Set 7 | geraldton
# Processing Record 24 of Set 7 | evensk
# Processing Record 25 of Set 7 | atar
# Processing Record 26 of Set 7 | garowe
# Processing Record 27 of Set 7 | hamilton
# Processing Record 28 of Set 7 | tateyama
# Processing Record 29 of Set 7 | havoysund
# Processing Record 30 of Set 7 | ancud
# Processing Record 31 of Set 7 | baoshan
# Processing Record 32 of Set 7 | pyapon
# Processing Record 33 of Set 7 | ewa beach
# Processing Record 34 of Set 7 | sabha
# Processing Record 35 of Set 7 | riyadh
# Processing Record 36 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set
# Processing Record 1 of Set 9 | namatanai
# Processing Record 2 of Set 9 | bairiki
# Processing Record 3 of Set 9 | iqaluit
# Processing Record 4 of Set 9 | cusuna
# Processing Record 5 of Set 9 | baykit
# Processing Record 6 of Set 9 | arlit
# Processing Record 7 of Set 9 | calama
# Processing Record 8 of Set 9 | marly
# Processing Record 9 of Set 9 | rawson
# Processing Record 10 of Set 9 | wanaka
# Processing Record 11 of Set 9 | bodden town
# Processing Record 12 of Set 9 | platonovka
# Processing Record 13 of Set 9 | palembang
# Processing Record 14 of Set 9 | olafsvik
# Processing Record 15 of Set 9 | flinders
# Processing Record 16 of Set 9 | kavieng
# Processing Record 17 of Set 9 | antissa
# City not found. Skipping...
# Processing Record 18 of Set 9 | marsa matruh
# Processing Record 19 of Set 9 | aykhal
# Processing Record 20 of Set 9 | mitu
# Processing Record 21 of Set 9 | zaltan
# Processing Record 22 of Set 9 | bolobo
# Processing Record 23 of Set 9 | douglas
# Processing Record 24 of Set 9 | clyde river
# Processing Record 25 of Set 9 | tuatapere
# Processing Record 26 of Set 9 | penzance
# Processing Record 27 of Set 9 | bure
# Processing Record 28 of Set 9 | rodrigues alves
# Processing Record 29 of Set 9 | the valley
# Processing Record 30 of Set 9 | liyang
# Processing Record 31 of Set 9 | brigantine
# Processing Record 32 of Set 9 | umm kaddadah
# Processing Record 33 of Set 9 | enshi
# Processing Record 34 of Set 9 | ciudad bolivar
# Processing Record 35 of Set 9 | santiago del estero
# Processing Record 36 of Set 9 | miles city
# Processing Record 37 of Set 9 | domoni
# Processing Record 38 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 39 of Set 9 | teguise
# Processing Record 40 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 9 | padang
# Processing Record 42 of Set 9 | lavrentiya
# Processing Record 43 of Set 9 | biltine
# Processing Record 44 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 9 | huarmey
# Processing Record 46 of Set 9 | ati
# Processing Record 47 of Set 9 | brae
# Processing Record 48 of Set 9 | paka
# Processing Record 49 of Set 9 | telenesti
# Processing Record 50 of Set 9 | taganak
# Processing Record 1 of Set 10 | mumbwa
# Processing Record 2 of Set 10 | nakanojo
# Processing Record 3 of Set 10 | alofi
# Processing Record 4 of Set 10 | roma
# Processing Record 5 of Set 10 | port keats
# Processing Record 6 of Set 10 | paidha
# Processing Record 7 of Set 10 | kushima
# Processing Record 8 of Set 10 | eureka
# Processing Record 9 of Set 10 | key west
# Processing Record 10 of Set 10 | norrkoping
# Processing Record 11 of Set 10 | kyshtovka
# Processing Record 12 of Set 10 | severo-kurilsk
# Processing Record 13 of Set 10 | anito
# Processing Record 14 of Set 10 | alta gracia
# Processing Record 15 of Set 10 | pasighat
# Processing Record 16 of Set 10 | siocon
# Processing Record 17 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 10 | lensk
# Processing Record 19 of Set 10 | kununurra
# Processing Record 20 of Set 10 | buin
# Processing Record 21 of Set 10 | khorixas
# Processing Record 22 of Set 10 | kopychyntsi
# Processing Record 23 of Set 10 | techiman
# Processing Record 24 of Set 10 | kailua
# Processing Record 25 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 10 | la palma
# Processing Record 27 of Set 10 | kjollefjord
# Processing Record 28 of Set 10 | naryan-mar
# Processing Record 29 of Set 10 | nichlaul
# Processing Record 30 of Set 10 | mariakani
# Processing Record 31 of Set 10 | manyana
# Processing Record 32 of Set 10 | kavaratti
# Processing Record 33 of Set 10 | khatanga
# Processing Record 34 of Set 10 | gwadar
# Processing Record 35 of Set 10 | shimoda
# Processing Record 36 of Set 10 | netivot
# Processing Record 37 of Set 10 | araguatins
# City not found. Skipping...
# Processing Record 38 of Set 10 | oak ridge
# Processing Record 39 of Set 10 | lapi
# Processing Record 40 of Set 10 | teacapan
# Processing Record 41 of Set 10 | bafoussam
# Processing Record 42 of Set 10 | pasni
# Processing Record 43 of Set 10 | parrsboro
# Processing Record 44 of Set 10 | poyarkovo
# Processing Record 45 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 46 of Set 10 | basco
# Processing Record 47 of Set 10 | terrace
# Processing Record 48 of Set 10 | tanete
# Processing Record 49 of Set 10 | south lake tahoe
# Processing Record 50 of Set 10 | coffs harbour
# Processing Record 1 of Set 11 | chaplynka
# Processing Record 2 of Set 11 | jumla
# Processing Record 3 of Set 11 | mabaruma
# Processing Record 4 of Set 11 | talnakh
# Processing Record 5 of Set 11 | yekimovichi
# Processing Record 6 of Set 11 | ha tinh
# Processing Record 7 of Set 11 | mayskiy
# Processing Record 8 of Set 11 | mazamari
# Processing Record 9 of Set 11 | truth or consequences
# Processing Record 10 of Set 11 | kasane
# Processing Record 11 of Set 11 | altoona
# Processing Record 12 of Set 11 | ko samui
# Processing Record 13 of Set 11 | pringsewu
# Processing Record 14 of Set 11 | gat
# Processing Record 15 of Set 11 | vestmannaeyjar
# Processing Record 16 of Set 11 | bay roberts
# Processing Record 17 of Set 11 | harper
# Processing Record 18 of Set 11 | nelson bay
# Processing Record 19 of Set 11 | shache
# Processing Record 20 of Set 11 | mooi river
# City not found. Skipping...
# Processing Record 21 of Set 11 | wuhu
# Processing Record 22 of Set 11 | talara
# Processing Record 23 of Set 11 | grand gaube
# Processing Record 24 of Set 11 | chalus
# Processing Record 25 of Set 11 | oksfjord
# Processing Record 26 of Set 11 | teguldet
# Processing Record 27 of Set 11 | tezu
# Processing Record 28 of Set 11 | monte san giovanni campano
# Processing Record 29 of Set 11 | tieli
# Processing Record 30 of Set 11 | mastung
# Processing Record 31 of Set 11 | pangnirtung
# Processing Record 32 of Set 11 | laguna
# Processing Record 33 of Set 11 | latung
# Processing Record 34 of Set 11 | thinadhoo
# Processing Record 35 of Set 11 | orlovskiy
# Processing Record 36 of Set 11 | susangerd
# Processing Record 37 of Set 11 | saint anthony
# Processing Record 38 of Set 11 | bull savanna
# Processing Record 39 of Set 11 | springville
# Processing Record 40 of Set 11 | belmonte
# Processing Record 41 of Set 11 | litovko
# Processing Record 42 of Set 11 | mana
# Processing Record 43 of Set 11 | college
# Processing Record 44 of Set 11 | moche
# Processing Record 45 of Set 11 | aklavik
# Processing Record 46 of Set 11 | lahij
# Processing Record 47 of Set 11 | sayat
# Processing Record 48 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 11 | maniitsoq
# Processing Record 50 of Set 11 | kutum
# Processing Record 1 of Set 12 | stephenville
# Processing Record 2 of Set 12 | tessalit
# Processing Record 3 of Set 12 | huzhou
# Processing Record 4 of Set 12 | eyl
# Processing Record 5 of Set 12 | wamba
# Processing Record 6 of Set 12 | lata
# Processing Record 7 of Set 12 | sena madureira
# Processing Record 8 of Set 12 | tilichiki
# Processing Record 9 of Set 12 | cap malheureux
# Processing Record 10 of Set 12 | nuristan
# Processing Record 11 of Set 12 | parana
# Processing Record 12 of Set 12 | abha
# Processing Record 13 of Set 12 | tongren
# Processing Record 14 of Set 12 | lazaro cardenas
# Processing Record 15 of Set 12 | sokolo
# Processing Record 16 of Set 12 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 17 of Set 12 | hopelchen
# Processing Record 18 of Set 12 | talaya
# Processing Record 19 of Set 12 | labuhan
# Processing Record 20 of Set 12 | parras
# City not found. Skipping...
# Processing Record 21 of Set 12 | sanary-sur-mer
# Processing Record 22 of Set 12 | momcilgrad
# City not found. Skipping...
# Processing Record 23 of Set 12 | tammisaari
# Processing Record 24 of Set 12 | russell
# Processing Record 25 of Set 12 | hofn
# Processing Record 26 of Set 12 | tuni
# Processing Record 27 of Set 12 | chandil
# Processing Record 28 of Set 12 | husavik
# Processing Record 29 of Set 12 | grants
# Processing Record 30 of Set 12 | pokaran
# Processing Record 31 of Set 12 | mogocha
# Processing Record 32 of Set 12 | upata
# Processing Record 33 of Set 12 | hualmay
# Processing Record 34 of Set 12 | fort nelson
# Processing Record 35 of Set 12 | sperkhias
# City not found. Skipping...
# Processing Record 36 of Set 12 | hovd
# Processing Record 37 of Set 12 | encheng
# Processing Record 38 of Set 12 | neepawa
# Processing Record 39 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 12 | puerto ayacucho
# Processing Record 42 of Set 12 | carpentras
# Processing Record 43 of Set 12 | shar
# Processing Record 44 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 12 | gimli
# Processing Record 46 of Set 12 | oistins
# Processing Record 47 of Set 12 | lahad datu
# Processing Record 48 of Set 12 | alyangula
# Processing Record 49 of Set 12 | yarmouth
# Processing Record 50 of Set 12 | quatre cocos
# Processing Record 1 of Set 13 | varhaug
# Processing Record 2 of Set 13 | lusambo
# Processing Record 3 of Set 13 | nata
# Processing Record 4 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 5 of Set 13 | mazatlan
# Processing Record 6 of Set 13 | mayumba
# Processing Record 7 of Set 13 | gawler
# Processing Record 8 of Set 13 | san quintin
# Processing Record 9 of Set 13 | port hedland
# Processing Record 10 of Set 13 | natitingou
# Processing Record 11 of Set 13 | sakaiminato
# Processing Record 12 of Set 13 | nishihara
# Processing Record 13 of Set 13 | vilhena
# Processing Record 14 of Set 13 | yumen
# Processing Record 15 of Set 13 | cairns
# Processing Record 16 of Set 13 | mayo
# Processing Record 17 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 13 | deputatskiy
# Processing Record 20 of Set 13 | nazare
# Processing Record 21 of Set 13 | kamenka
# Processing Record 22 of Set 13 | tromso
# Processing Record 23 of Set 13 | lanzhou
# Processing Record 24 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 26 of Set 13 | zhanaozen
# Processing Record 27 of Set 13 | macea
# Processing Record 28 of Set 13 | collie
# Processing Record 29 of Set 13 | ambon
# Processing Record 30 of Set 13 | santa cruz
# Processing Record 31 of Set 13 | moron
# Processing Record 32 of Set 13 | san juan de uraba
# Processing Record 33 of Set 13 | ribas do rio pardo
# Processing Record 34 of Set 13 | doha
# Processing Record 35 of Set 13 | corralillo
# Processing Record 36 of Set 13 | kita
# Processing Record 37 of Set 13 | leh
# Processing Record 38 of Set 13 | guerrero negro
# Processing Record 39 of Set 13 | meulaboh
# Processing Record 40 of Set 13 | rizhao
# Processing Record 41 of Set 13 | turinsk
# Processing Record 42 of Set 13 | keta
# Processing Record 43 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 13 | trairi
# Processing Record 45 of Set 13 | kijang
# Processing Record 46 of Set 13 | tambovka
# Processing Record 47 of Set 13 | muriwai beach
# Processing Record 48 of Set 13 | milkovo
# Processing Record 49 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 50 of Set 13 | lima duarte
# Processing Record 1 of Set 14 | portland
# Processing Record 2 of Set 14 | lakatoro
# Processing Record 3 of Set 14 | troy
# Processing Record 4 of Set 14 | praia da vitoria
# Processing Record 5 of Set 14 | gweta
# Processing Record 6 of Set 14 | dwarka
# Processing Record 7 of Set 14 | roald
# Processing Record 8 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 14 | terrace bay
# Processing Record 10 of Set 14 | san patricio
# Processing Record 11 of Set 14 | alice springs
# Processing Record 12 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 14 | novyy karachay
# Processing Record 14 of Set 14 | hanumangarh
# Processing Record 15 of Set 14 | fallon
# Processing Record 16 of Set 14 | kurilsk
# Processing Record 17 of Set 14 | chicama
# Processing Record 18 of Set 14 | conceicao da barra
# Processing Record 19 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 14 | wakkanai
# Processing Record 21 of Set 14 | anadyr
# Processing Record 22 of Set 14 | newcastleton
# Processing Record 23 of Set 14 | athabasca
# Processing Record 24 of Set 14 | reitz
# Processing Record 25 of Set 14 | hinton
# Processing Record 26 of Set 14 | samfya
# Processing Record 27 of Set 14 | ihosy
# Processing Record 28 of Set 14 | malakal
# Processing Record 29 of Set 14 | wasilla
# Processing Record 30 of Set 14 | jalu
# Processing Record 31 of Set 14 | kashary
# Processing Record 32 of Set 14 | lengshuitan
# Processing Record 33 of Set 14 | ankara
# Processing Record 34 of Set 14 | araouane
# Processing Record 35 of Set 14 | sakakah
# Processing Record 36 of Set 14 | wattegama
# Processing Record 37 of Set 14 | asau
# Processing Record 38 of Set 14 | kathu
# Processing Record 39 of Set 14 | mortka
# Processing Record 40 of Set 14 | maniwaki
# Processing Record 41 of Set 14 | henties bay
# Processing Record 42 of Set 14 | yazman
# Processing Record 43 of Set 14 | qinnan
# Processing Record 44 of Set 14 | poum
# Processing Record 45 of Set 14 | vao
# Processing Record 46 of Set 14 | cidreira
# Processing Record 47 of Set 14 | guadalajara
# Processing Record 48 of Set 14 | cerrito
# Processing Record 49 of Set 14 | homer
# Processing Record 50 of Set 14 | diego de almagro
# Processing Record 1 of Set 15 | srivardhan
# Processing Record 2 of Set 15 | great falls
# Processing Record 3 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 15 | tambura
# Processing Record 5 of Set 15 | petrachioaia
# Processing Record 6 of Set 15 | chinsali
# Processing Record 7 of Set 15 | terracina
# Processing Record 8 of Set 15 | pisco
# Processing Record 9 of Set 15 | richards bay
# Processing Record 10 of Set 15 | plettenberg bay
# Processing Record 11 of Set 15 | churapcha
# Processing Record 12 of Set 15 | kalmunai
# Processing Record 13 of Set 15 | barauna
# Processing Record 14 of Set 15 | olavarria
# Processing Record 15 of Set 15 | portlethen
# Processing Record 16 of Set 15 | borzna
# Processing Record 17 of Set 15 | balkhash
# Processing Record 18 of Set 15 | suksun
# Processing Record 19 of Set 15 | sahuaripa
# Processing Record 20 of Set 15 | stokmarknes
# Processing Record 21 of Set 15 | janoshaza
# Processing Record 22 of Set 15 | saint-michel-des-saints
# Processing Record 23 of Set 15 | puerto madero
# Processing Record 24 of Set 15 | nouakchott
# Processing Record 25 of Set 15 | lydenburg
# Processing Record 26 of Set 15 | saint-leu
# Processing Record 27 of Set 15 | burns lake
# Processing Record 28 of Set 15 | radyvyliv
# Processing Record 29 of Set 15 | mogadishu
# Processing Record 30 of Set 15 | collingwood
# Processing Record 31 of Set 15 | koshki
# Processing Record 32 of Set 15 | messias
# Processing Record 33 of Set 15 | baruun-urt
# Processing Record 34 of Set 15 | batagay-alyta
# Processing Record 35 of Set 15 | mareeba
# Processing Record 36 of Set 15 | alapur
# Processing Record 37 of Set 15 | storforshei
# Processing Record 38 of Set 15 | butembo
# Processing Record 39 of Set 15 | chute-aux-outardes
# Processing Record 40 of Set 15 | altavas
# Processing Record 41 of Set 15 | west fargo
# Processing Record 42 of Set 15 | galion
# Processing Record 43 of Set 15 | teya
# Processing Record 44 of Set 15 | qeshm
# Processing Record 45 of Set 15 | valparaiso
# Processing Record 46 of Set 15 | tahe
# Processing Record 47 of Set 15 | takayama
# Processing Record 48 of Set 15 | nouadhibou
# Processing Record 49 of Set 15 | ursulo galvan
# Processing Record 50 of Set 15 | hay river
# Processing Record 1 of Set 16 | ocampo
# Processing Record 2 of Set 16 | ust-kuyga
# Processing Record 3 of Set 16 | aswan
# Processing Record 4 of Set 16 | bonito
# Processing Record 5 of Set 16 | patos de minas
# Processing Record 6 of Set 16 | fairbanks
# Processing Record 7 of Set 16 | izumo
# Processing Record 8 of Set 16 | kollam
# Processing Record 9 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 16 | severnoye
# Processing Record 11 of Set 16 | shakawe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# city_url = url + "&q=" + city.replace(" ", "+")
# city_weather = requests.get(city_url).json()
# city_weather

# %%
city_data
# Out:
# [{'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.01,
#   'Current Description': 'scattered clouds',
#   'Humidity': 76,
#   'Cloudiness': 33,
#   'Wind Speed': 21.88,
#   'Country': 'PF'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.77,
#   'Current Description': 'moderate rain',
#   'Humidity': 79,
#   'Cloudiness': 19,
#   'Wind Speed': 16.82,
#   'Country': 'KI'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.89,
#   'Current Description': 'light rain',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 24.81,
#   'Country': 'PF'},
#  {'City': 'Pontal Do Parana',
#   'Lat': -25.6533,
#   'Lng': -48.5128,
#   'Max Temp': 86.2,
#   'Current Description': 'scattered clouds',
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'BR'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 71.46,
#   'Current Description': 'clear sky',
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Capinopolis',
#   'Lat': -18.6819,
#   'Lng': -49.5697,
#   'Max Temp': 91.02,
#   'Current Description': 'clear sky',
#   'Humidity': 28,
#   'Cloudiness': 2,
#   'Wind Speed': 6.89,
#   'Country': 'BR'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 44.46,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'NZ'},
#  {'City': 'Dubbo',
#   'Lat': -32.25,
#   'Lng': 148.6167,
#   'Max Temp': 60.93,
#   'Current Description': 'clear sky',
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'AU'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 65.08,
#   'Current Description': 'broken clouds',
#   'Humidity': 80,
#   'Cloudiness': 61,
#   'Wind Speed': 8.79,
#   'Country': 'ZA'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 60.53,
#   'Current Description': 'few clouds',
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'CL'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 23,
#   'Current Description': 'broken clouds',
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'CA'},
#  {'City': 'Galich',
#   'Lat': 58.3797,
#   'Lng': 42.3475,
#   'Max Temp': 44.08,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 91,
#   'Wind Speed': 13.09,
#   'Country': 'RU'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -1.61,
#   'Current Description': 'clear sky',
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 8.43,
#   'Country': 'GL'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 84.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 66,
#   'Cloudiness': 38,
#   'Wind Speed': 12.24,
#   'Country': 'BR'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.96,
#   'Current Description': 'broken clouds',
#   'Humidity': 64,
#   'Cloudiness': 76,
#   'Wind Speed': 18.03,
#   'Country': 'CL'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 63.01,
#   'Current Description': 'clear sky',
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 73.27,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 76.96,
#   'Current Description': 'clear sky',
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'BR'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 60.12,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'ZA'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 38.41,
#   'Current Description': 'few clouds',
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'CA'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 74.71,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.36,
#   'Country': 'PH'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 70.74,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 17.18,
#   'Country': 'AO'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 82.18,
#   'Current Description': 'overcast clouds',
#   'Humidity': 65,
#   'Cloudiness': 96,
#   'Wind Speed': 2.59,
#   'Country': 'MX'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 49.66,
#   'Current Description': 'scattered clouds',
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 24.16,
#   'Country': 'AR'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 65.34,
#   'Current Description': 'clear sky',
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ZA'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 49.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01,
#   'Country': 'US'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 57.83,
#   'Current Description': 'clear sky',
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 16.44,
#   'Country': 'CL'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 53.47,
#   'Current Description': 'clear sky',
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'FR'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 48.31,
#   'Current Description': 'broken clouds',
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 36.82,
#   'Country': 'CL'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 43.97,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 1.95,
#   'Country': 'NZ'},
#  {'City': 'Imeni Poliny Osipenko',
#   'Lat': 52.4201,
#   'Lng': 136.4853,
#   'Max Temp': 25.12,
#   'Current Description': 'broken clouds',
#   'Humidity': 95,
#   'Cloudiness': 82,
#   'Wind Speed': 5.23,
#   'Country': 'RU'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 73.35,
#   'Current Description': 'broken clouds',
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'BR'},
#  {'City': 'Kirgiz-Miyaki',
#   'Lat': 53.6324,
#   'Lng': 54.7979,
#   'Max Temp': 48.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 20.2,
#   'Country': 'RU'},
#  {'City': 'Meadow Lake',
#   'Lat': 34.8014,
#   'Lng': -106.5436,
#   'Max Temp': 68.43,
#   'Current Description': 'clear sky',
#   'Humidity': 20,
#   'Cloudiness': 5,
#   'Wind Speed': 4.09,
#   'Country': 'US'},
#  {'City': 'Coolidge',
#   'Lat': 32.9778,
#   'Lng': -111.5176,
#   'Max Temp': 77.04,
#   'Current Description': 'clear sky',
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 71.55,
#   'Current Description': 'clear sky',
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 79.18,
#   'Current Description': 'clear sky',
#   'Humidity': 74,
#   'Cloudiness': 9,
#   'Wind Speed': 10.11,
#   'Country': 'SO'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 33.8,
#   'Current Description': 'light shower snow',
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'NO'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 72.9,
#   'Current Description': 'clear sky',
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 0.29,
#   'Country': 'BR'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 21.22,
#   'Current Description': 'broken clouds',
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'GL'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 88.25,
#   'Current Description': 'clear sky',
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 11.34,
#   'Country': 'SA'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 53.37,
#   'Current Description': 'overcast clouds',
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 50.09,
#   'Current Description': 'clear sky',
#   'Humidity': 74,
#   'Cloudiness': 7,
#   'Wind Speed': 7.36,
#   'Country': 'AU'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 47.88,
#   'Current Description': 'light rain',
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 18.92,
#   'Country': 'RU'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 33.78,
#   'Current Description': 'light rain',
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'NO'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 75.45,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'MU'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 58.12,
#   'Current Description': 'moderate rain',
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'AU'},
#  {'City': 'Kitimat',
#   'Lat': 54.0524,
#   'Lng': -128.6534,
#   'Max Temp': 48.58,
#   'Current Description': 'light rain',
#   'Humidity': 29,
#   'Cloudiness': 99,
#   'Wind Speed': 3.74,
#   'Country': 'CA'},
#  {'City': 'Boa Vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 82.38,
#   'Current Description': 'overcast clouds',
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'BR'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 69.96,
#   'Current Description': 'scattered clouds',
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'TO'},
#  {'City': 'Posse',
#   'Lat': -14.0931,
#   'Lng': -46.3694,
#   'Max Temp': 86.22,
#   'Current Description': 'broken clouds',
#   'Humidity': 46,
#   'Cloudiness': 79,
#   'Wind Speed': 1.52,
#   'Country': 'BR'},
#  {'City': 'Madang',
#   'Lat': -5.2246,
#   'Lng': 145.7966,
#   'Max Temp': 76.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'PG'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 76.59,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 85,
#   'Wind Speed': 7.36,
#   'Country': 'RE'},
#  {'City': 'Mahon',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 64.96,
#   'Current Description': 'few clouds',
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'ES'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 59.09,
#   'Current Description': 'moderate rain',
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'AR'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 38.32,
#   'Current Description': 'broken clouds',
#   'Humidity': 54,
#   'Cloudiness': 81,
#   'Wind Speed': 5.44,
#   'Country': 'FO'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 48.42,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 2.37,
#   'Country': 'NZ'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 60.85,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 21.72,
#   'Country': 'ZA'},
#  {'City': 'Skreia',
#   'Lat': 60.65,
#   'Lng': 10.9333,
#   'Max Temp': 45.34,
#   'Current Description': 'broken clouds',
#   'Humidity': 51,
#   'Cloudiness': 64,
#   'Wind Speed': 9.15,
#   'Country': 'NO'},
#  {'City': 'Boden',
#   'Lat': 65.8252,
#   'Lng': 21.6886,
#   'Max Temp': 32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 14.18,
#   'Country': 'SE'},
#  {'City': 'Mrakovo',
#   'Lat': 52.7161,
#   'Lng': 56.6244,
#   'Max Temp': 47.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 15.99,
#   'Country': 'RU'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 57.76,
#   'Current Description': 'heavy intensity rain',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 0.18,
#   'Country': 'AU'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 60.44,
#   'Current Description': 'clear sky',
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 11.14,
#   'Country': 'NA'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 68.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'HK'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 62.89,
#   'Current Description': 'few clouds',
#   'Humidity': 68,
#   'Cloudiness': 23,
#   'Wind Speed': 5.46,
#   'Country': 'ZA'},
#  {'City': 'Adamas',
#   'Lat': 36.7333,
#   'Lng': 24.4333,
#   'Max Temp': 67.42,
#   'Current Description': 'clear sky',
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 2.55,
#   'Country': 'GR'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -3.39,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Country': 'RU'},
#  {'City': 'Halifax',
#   'Lat': 44.6453,
#   'Lng': -63.5724,
#   'Max Temp': 71.42,
#   'Current Description': 'broken clouds',
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 8.99,
#   'Country': 'CA'},
#  {'City': 'Pitimbu',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 88.39,
#   'Current Description': 'overcast clouds',
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 11.16,
#   'Country': 'BR'},
#  {'City': 'Quelimane',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 76.95,
#   'Current Description': 'clear sky',
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'MZ'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 39.9,
#   'Current Description': 'broken clouds',
#   'Humidity': 62,
#   'Cloudiness': 79,
#   'Wind Speed': 2.77,
#   'Country': 'CN'},
#  {'City': 'Mecca',
#   'Lat': 21.4267,
#   'Lng': 39.8261,
#   'Max Temp': 86.5,
#   'Current Description': 'clear sky',
#   'Humidity': 47,
#   'Cloudiness': 5,
#   'Wind Speed': 5.17,
#   'Country': 'SA'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 82.51,
#   'Current Description': 'clear sky',
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'MX'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 45.91,
#   'Current Description': 'overcast clouds',
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 30.36,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'CA'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 35.76,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.5,
#   'Country': 'GL'},
#  {'City': 'Nhulunbuy',
#   'Lat': -12.2333,
#   'Lng': 136.7667,
#   'Max Temp': 81.21,
#   'Current Description': 'scattered clouds',
#   'Humidity': 89,
#   'Cloudiness': 33,
#   'Wind Speed': 5.75,
#   'Country': 'AU'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.39,
#   'Current Description': 'light rain',
#   'Humidity': 75,
#   'Cloudiness': 24,
#   'Wind Speed': 7.99,
#   'Country': 'MV'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 84.16,
#   'Current Description': 'scattered clouds',
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'TC'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 84.38,
#   'Current Description': 'scattered clouds',
#   'Humidity': 46,
#   'Cloudiness': 34,
#   'Wind Speed': 6.46,
#   'Country': 'VE'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 10.04,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 2.08,
#   'Country': 'RU'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.52,
#   'Current Description': 'light rain',
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'US'},
#  {'City': 'Semey',
#   'Lat': 50.4111,
#   'Lng': 80.2275,
#   'Max Temp': 39.42,
#   'Current Description': 'broken clouds',
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'KZ'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 35.58,
#   'Current Description': 'clear sky',
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'NO'},
#  {'City': 'Kushiro',
#   'Lat': 42.975,
#   'Lng': 144.3747,
#   'Max Temp': 40.98,
#   'Current Description': 'scattered clouds',
#   'Humidity': 92,
#   'Cloudiness': 40,
#   'Wind Speed': 5.1,
#   'Country': 'JP'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 62.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 68,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 79.95,
#   'Current Description': 'broken clouds',
#   'Humidity': 81,
#   'Cloudiness': 72,
#   'Wind Speed': 3.78,
#   'Country': 'ID'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 39.24,
#   'Current Description': 'broken clouds',
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'CA'},
#  {'City': 'Da Nang',
#   'Lat': 16.0678,
#   'Lng': 108.2208,
#   'Max Temp': 73.45,
#   'Current Description': 'shower rain',
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'VN'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 82.22,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'MX'},
#  {'City': 'Tepelene',
#   'Lat': 40.2958,
#   'Lng': 20.0192,
#   'Max Temp': 62.74,
#   'Current Description': 'scattered clouds',
#   'Humidity': 84,
#   'Cloudiness': 43,
#   'Wind Speed': 5.97,
#   'Country': 'AL'},
#  {'City': 'Navalmoral De La Mata',
#   'Lat': 39.8916,
#   'Lng': -5.5406,
#   'Max Temp': 72.95,
#   'Current Description': 'clear sky',
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 1.95,
#   'Country': 'ES'},
#  {'City': 'Vejalpur',
#   'Lat': 22.6833,
#   'Lng': 73.5667,
#   'Max Temp': 77.92,
#   'Current Description': 'clear sky',
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 7.05,
#   'Country': 'IN'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 85.68,
#   'Current Description': 'broken clouds',
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 23.02,
#   'Country': 'GD'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 53.55,
#   'Current Description': 'broken clouds',
#   'Humidity': 37,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CL'},
#  {'City': 'Ambatofinandrahana',
#   'Lat': -20.55,
#   'Lng': 46.8,
#   'Max Temp': 68.09,
#   'Current Description': 'broken clouds',
#   'Humidity': 39,
#   'Cloudiness': 72,
#   'Wind Speed': 5.82,
#   'Country': 'MG'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 78.89,
#   'Current Description': 'broken clouds',
#   'Humidity': 73,
#   'Cloudiness': 59,
#   'Wind Speed': 7.58,
#   'Country': 'BR'},
#  {'City': 'Kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 79.54,
#   'Current Description': 'scattered clouds',
#   'Humidity': 85,
#   'Cloudiness': 48,
#   'Wind Speed': 4.83,
#   'Country': 'ID'},
#  {'City': 'Honningsvag',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 33.55,
#   'Current Description': 'broken clouds',
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'NO'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 42.31,
#   'Current Description': 'overcast clouds',
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 21.85,
#   'Country': 'US'},
#  {'City': 'Marondera',
#   'Lat': -18.1853,
#   'Lng': 31.5519,
#   'Max Temp': 75.54,
#   'Current Description': 'broken clouds',
#   'Humidity': 28,
#   'Cloudiness': 83,
#   'Wind Speed': 3.18,
#   'Country': 'ZW'},
#  {'City': 'Biankouma',
#   'Lat': 7.7391,
#   'Lng': -7.6138,
#   'Max Temp': 79.86,
#   'Current Description': 'light rain',
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 1.97,
#   'Country': 'CI'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 55.89,
#   'Current Description': 'scattered clouds',
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'CA'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 88.7,
#   'Current Description': 'broken clouds',
#   'Humidity': 61,
#   'Cloudiness': 62,
#   'Wind Speed': 13.58,
#   'Country': 'BR'},
#  {'City': 'Verkhoyansk',
#   'Lat': 67.5447,
#   'Lng': 133.385,
#   'Max Temp': 6.64,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 96,
#   'Wind Speed': 2.3,
#   'Country': 'RU'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 82.45,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.89,
#   'Country': 'MX'},
#  {'City': 'Tocopilla',
#   'Lat': -22.092,
#   'Lng': -70.1979,
#   'Max Temp': 66.09,
#   'Current Description': 'clear sky',
#   'Humidity': 65,
#   'Cloudiness': 8,
#   'Wind Speed': 9.26,
#   'Country': 'CL'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 38.89,
#   'Current Description': 'moderate rain',
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'GL'},
#  {'City': 'Kurumkan',
#   'Lat': 54.3,
#   'Lng': 110.3,
#   'Max Temp': 33.24,
#   'Current Description': 'scattered clouds',
#   'Humidity': 65,
#   'Cloudiness': 26,
#   'Wind Speed': 3.22,
#   'Country': 'RU'},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.1667,
#   'Max Temp': 20.46,
#   'Current Description': 'overcast clouds',
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38,
#   'Country': 'RU'},
#  {'City': 'Pingliang',
#   'Lat': 35.5392,
#   'Lng': 106.6861,
#   'Max Temp': 40.73,
#   'Current Description': 'scattered clouds',
#   'Humidity': 81,
#   'Cloudiness': 25,
#   'Wind Speed': 4.94,
#   'Country': 'CN'},
#  {'City': 'Bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 81.57,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.21,
#   'Country': 'SL'},
#  {'City': 'Balakhta',
#   'Lat': 55.38,
#   'Lng': 91.6,
#   'Max Temp': 40.87,
#   'Current Description': 'light rain',
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 13.91,
#   'Country': 'RU'},
#  {'City': 'Pacifica',
#   'Lat': 37.6138,
#   'Lng': -122.4869,
#   'Max Temp': 58.84,
#   'Current Description': 'mist',
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 76.12,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 0.92,
#   'Country': 'MG'},
#  {'City': 'Basoko',
#   'Lat': 1.2391,
#   'Lng': 23.616,
#   'Max Temp': 75.36,
#   'Current Description': 'scattered clouds',
#   'Humidity': 83,
#   'Cloudiness': 47,
#   'Wind Speed': 3.27,
#   'Country': 'CD'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 72,
#   'Current Description': 'few clouds',
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'PT'},
#  {'City': 'Porbandar',
#   'Lat': 21.6422,
#   'Lng': 69.6093,
#   'Max Temp': 80.11,
#   'Current Description': 'clear sky',
#   'Humidity': 61,
#   'Cloudiness': 3,
#   'Wind Speed': 10.29,
#   'Country': 'IN'},
#  {'City': 'Salekhard',
#   'Lat': 66.53,
#   'Lng': 66.6019,
#   'Max Temp': 27.95,
#   'Current Description': 'light snow',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Country': 'RU'},
#  {'City': 'Dole',
#   'Lat': 47.0833,
#   'Lng': 5.5,
#   'Max Temp': 53.51,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'FR'},
#  {'City': 'Sao Bento Do Sul',
#   'Lat': -26.2503,
#   'Lng': -49.3786,
#   'Max Temp': 71.24,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 1.43,
#   'Country': 'BR'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 33.58,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 10.85,
#   'Country': 'CA'},
#  {'City': 'Da Lat',
#   'Lat': 11.9465,
#   'Lng': 108.4419,
#   'Max Temp': 58.77,
#   'Current Description': 'broken clouds',
#   'Humidity': 98,
#   'Cloudiness': 51,
#   'Wind Speed': 2.28,
#   'Country': 'VN'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 73.71,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 5.5,
#   'Country': 'PT'},
#  {'City': 'Itaqui',
#   'Lat': -29.1253,
#   'Lng': -56.5531,
#   'Max Temp': 81.41,
#   'Current Description': 'clear sky',
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 7.36,
#   'Country': 'BR'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 64.27,
#   'Current Description': 'overcast clouds',
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 18.12,
#   'Country': 'ZA'},
#  {'City': 'Tomatlan',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 84.99,
#   'Current Description': 'scattered clouds',
#   'Humidity': 75,
#   'Cloudiness': 30,
#   'Wind Speed': 1.12,
#   'Country': 'MX'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 18.14,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 16.06,
#   'Country': 'RU'},
#  {'City': 'Corn Island',
#   'Lat': 12.1694,
#   'Lng': -83.0418,
#   'Max Temp': 82.44,
#   'Current Description': 'overcast clouds',
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 4,
#   'Country': 'NI'},
#  {'City': 'Lishui',
#   'Lat': 28.4604,
#   'Lng': 119.9103,
#   'Max Temp': 54.68,
#   'Current Description': 'light rain',
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.42,
#   'Country': 'CN'},
#  {'City': 'Verkhnevilyuysk',
#   'Lat': 63.4453,
#   'Lng': 120.3167,
#   'Max Temp': 31.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.79,
#   'Country': 'RU'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 75.58,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'RE'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 76.68,
#   'Current Description': 'scattered clouds',
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'RE'},
#  {'City': 'Blythe',
#   'Lat': 33.6103,
#   'Lng': -114.5964,
#   'Max Temp': 77.67,
#   'Current Description': 'scattered clouds',
#   'Humidity': 17,
#   'Cloudiness': 44,
#   'Wind Speed': 0.36,
#   'Country': 'US'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 79.9,
#   'Current Description': 'scattered clouds',
#   'Humidity': 90,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'MY'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -14.98,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 96,
#   'Wind Speed': 2.3,
#   'Country': 'RU'},
#  {'City': 'Ginda',
#   'Lat': 30.6945,
#   'Lng': 78.4932,
#   'Max Temp': 55.06,
#   'Current Description': 'clear sky',
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 5.46,
#   'Country': 'IN'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 40.89,
#   'Current Description': 'overcast clouds',
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Country': 'RU'},
#  {'City': 'Princeton',
#   'Lat': 25.5384,
#   'Lng': -80.4089,
#   'Max Temp': 80.98,
#   'Current Description': 'light rain',
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US'},
#  {'City': 'Kochki',
#   'Lat': 54.3358,
#   'Lng': 80.4806,
#   'Max Temp': 36.72,
#   'Current Description': 'scattered clouds',
#   'Humidity': 53,
#   'Cloudiness': 35,
#   'Wind Speed': 16.78,
#   'Country': 'RU'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 76.66,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Country': 'ID'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.01,
#   'Current Description': 'light rain',
#   'Humidity': 79,
#   'Cloudiness': 12,
#   'Wind Speed': 8.81,
#   'Country': 'PF'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 77.5,
#   'Current Description': 'few clouds',
#   'Humidity': 70,
#   'Cloudiness': 16,
#   'Wind Speed': 10.98,
#   'Country': 'PW'},
#  {'City': 'Russkiy Aktash',
#   'Lat': 55.0384,
#   'Lng': 52.1214,
#   'Max Temp': 51.15,
#   'Current Description': 'overcast clouds',
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 19.08,
#   'Country': 'RU'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 79.45,
#   'Current Description': 'few clouds',
#   'Humidity': 23,
#   'Cloudiness': 17,
#   'Wind Speed': 12.1,
#   'Country': 'SA'},
#  {'City': 'Sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 81.63,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 9.17,
#   'Country': 'GF'},
#  {'City': 'Qandala',
#   'Lat': 11.472,
#   'Lng': 49.8728,
#   'Max Temp': 81.52,
#   'Current Description': 'scattered clouds',
#   'Humidity': 56,
#   'Cloudiness': 32,
#   'Wind Speed': 6.49,
#   'Country': 'SO'},
#  {'City': 'Ossora',
#   'Lat': 59.2353,
#   'Lng': 163.0719,
#   'Max Temp': 19.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Country': 'RU'},
#  {'City': 'Aloleng',
#   'Lat': 16.1307,
#   'Lng': 119.7824,
#   'Max Temp': 80.49,
#   'Current Description': 'moderate rain',
#   'Humidity': 81,
#   'Cloudiness': 43,
#   'Wind Speed': 5.08,
#   'Country': 'PH'},
#  {'City': 'Placido De Castro',
#   'Lat': -10.3353,
#   'Lng': -67.1856,
#   'Max Temp': 97.7,
#   'Current Description': 'overcast clouds',
#   'Humidity': 36,
#   'Cloudiness': 86,
#   'Wind Speed': 4.94,
#   'Country': 'BR'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 76.96,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 91,
#   'Wind Speed': 9.98,
#   'Country': 'EC'},
#  {'City': 'Viesca',
#   'Lat': 25.35,
#   'Lng': -102.8,
#   'Max Temp': 73.76,
#   'Current Description': 'broken clouds',
#   'Humidity': 51,
#   'Cloudiness': 77,
#   'Wind Speed': 4.25,
#   'Country': 'MX'},
#  {'City': 'Half Moon Bay',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 59.11,
#   'Current Description': 'mist',
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Tripoli',
#   'Lat': 32.8752,
#   'Lng': 13.1875,
#   'Max Temp': 83.32,
#   'Current Description': 'scattered clouds',
#   'Humidity': 41,
#   'Cloudiness': 36,
#   'Wind Speed': 8.66,
#   'Country': 'LY'},
#  {'City': 'Pachora',
#   'Lat': 20.6667,
#   'Lng': 75.35,
#   'Max Temp': 75.16,
#   'Current Description': 'clear sky',
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 5.12,
#   'Country': 'IN'},
#  {'City': 'Maumere',
#   'Lat': -8.6199,
#   'Lng': 122.2111,
#   'Max Temp': 79.63,
#   'Current Description': 'broken clouds',
#   'Humidity': 79,
#   'Cloudiness': 76,
#   'Wind Speed': 3.44,
#   'Country': 'ID'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 56.43,
#   'Current Description': 'broken clouds',
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 5.99,
#   'Country': 'US'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 61.88,
#   'Current Description': 'few clouds',
#   'Humidity': 66,
#   'Cloudiness': 24,
#   'Wind Speed': 9.37,
#   'Country': 'CL'},
#  {'City': 'Biak',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 77.09,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 97,
#   'Wind Speed': 0.65,
#   'Country': 'ID'},
#  {'City': 'Coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 87.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 0.4,
#   'Country': 'MX'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 66.06,
#   'Current Description': 'clear sky',
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 25.32,
#   'Country': 'AR'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 51.69,
#   'Current Description': 'light rain',
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US'},
#  {'City': 'Atambua',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 76.28,
#   'Current Description': 'broken clouds',
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'ID'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 3.31,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Country': 'RU'},
#  {'City': 'Astoria',
#   'Lat': 46.1879,
#   'Lng': -123.8313,
#   'Max Temp': 53.85,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 64.8,
#   'Current Description': 'overcast clouds',
#   'Humidity': 72,
#   'Cloudiness': 97,
#   'Wind Speed': 27.29,
#   'Country': 'ZA'},
#  {'City': 'Antalaha',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 74.97,
#   'Current Description': 'broken clouds',
#   'Humidity': 92,
#   'Cloudiness': 84,
#   'Wind Speed': 1.23,
#   'Country': 'MG'},
#  {'City': 'Devils Lake',
#   'Lat': 48.1128,
#   'Lng': -98.8651,
#   'Max Temp': 39.31,
#   'Current Description': 'few clouds',
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 5.99,
#   'Country': 'US'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 90.39,
#   'Current Description': 'few clouds',
#   'Humidity': 74,
#   'Cloudiness': 15,
#   'Wind Speed': 10.49,
#   'Country': 'CV'},
#  {'City': 'Bitung',
#   'Lat': 1.4451,
#   'Lng': 125.1824,
#   'Max Temp': 77.85,
#   'Current Description': 'overcast clouds',
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'ID'},
#  {'City': 'Udachnyy',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 26.78,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 13.49,
#   'Country': 'RU'},
#  {'City': 'Sayyan',
#   'Lat': 15.1718,
#   'Lng': 44.3244,
#   'Max Temp': 62.01,
#   'Current Description': 'scattered clouds',
#   'Humidity': 33,
#   'Cloudiness': 32,
#   'Wind Speed': 14.88,
#   'Country': 'YE'},
#  {'City': 'Ranong',
#   'Lat': 9.9658,
#   'Lng': 98.6348,
#   'Max Temp': 76.69,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 88,
#   'Wind Speed': 2.21,
#   'Country': 'TH'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -0.83,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'RU'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 81.37,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 93,
#   'Wind Speed': 11.45,
#   'Country': 'GH'},
#  {'City': 'Bressuire',
#   'Lat': 46.9167,
#   'Lng': -0.5,
#   'Max Temp': 56.39,
#   'Current Description': 'clear sky',
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 7.27,
#   'Country': 'FR'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 51.64,
#   'Current Description': 'broken clouds',
#   'Humidity': 71,
#   'Cloudiness': 64,
#   'Wind Speed': 7.02,
#   'Country': 'AU'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 69.85,
#   'Current Description': 'broken clouds',
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CK'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 78.39,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Country': 'ID'},
#  {'City': 'Carberry',
#   'Lat': 49.8689,
#   'Lng': -99.3602,
#   'Max Temp': 34.03,
#   'Current Description': 'broken clouds',
#   'Humidity': 73,
#   'Cloudiness': 80,
#   'Wind Speed': 6.85,
#   'Country': 'CA'},
#  {'City': 'Morant Bay',
#   'Lat': 17.8815,
#   'Lng': -76.4093,
#   'Max Temp': 87.42,
#   'Current Description': 'scattered clouds',
#   'Humidity': 76,
#   'Cloudiness': 48,
#   'Wind Speed': 11.54,
#   'Country': 'JM'},
#  {'City': 'Tolyatti',
#   'Lat': 53.5303,
#   'Lng': 49.3461,
#   'Max Temp': 53.96,
#   'Current Description': 'overcast clouds',
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 17.02,
#   'Country': 'RU'},
#  {'City': 'Elizabeth City',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 79.02,
#   'Current Description': 'scattered clouds',
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 7,
#   'Country': 'US'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 26.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 52.68,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 8.41,
#   'Country': 'AU'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 18.1,
#   'Current Description': 'overcast clouds',
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 12.77,
#   'Country': 'RU'},
#  {'City': 'Surt',
#   'Lat': 31.2089,
#   'Lng': 16.5887,
#   'Max Temp': 81.63,
#   'Current Description': 'overcast clouds',
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 13.89,
#   'Country': 'LY'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 63,
#   'Current Description': 'broken clouds',
#   'Humidity': 80,
#   'Cloudiness': 82,
#   'Wind Speed': 2.3,
#   'Country': 'TL'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 75.76,
#   'Current Description': 'broken clouds',
#   'Humidity': 85,
#   'Cloudiness': 67,
#   'Wind Speed': 2.57,
#   'Country': 'VU'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 59.2,
#   'Current Description': 'mist',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Qasigiannguit',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': 21.45,
#   'Current Description': 'clear sky',
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 2.42,
#   'Country': 'GL'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 80.62,
#   'Current Description': 'scattered clouds',
#   'Humidity': 82,
#   'Cloudiness': 27,
#   'Wind Speed': 10.18,
#   'Country': 'LK'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 48.92,
#   'Current Description': 'scattered clouds',
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'UZ'},
#  {'City': 'Orlik',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': 28.92,
#   'Current Description': 'broken clouds',
#   'Humidity': 56,
#   'Cloudiness': 57,
#   'Wind Speed': 2.53,
#   'Country': 'RU'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 17.13,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 11.16,
#   'Country': 'GL'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 34.02,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 7.18,
#   'Country': 'RU'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 58.96,
#   'Current Description': 'clear sky',
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 3.56,
#   'Country': 'CN'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 67.59,
#   'Current Description': 'scattered clouds',
#   'Humidity': 70,
#   'Cloudiness': 27,
#   'Wind Speed': 13.56,
#   'Country': 'MG'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 19.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.21,
#   'Country': 'RU'},
#  {'City': 'Ust-Ishim',
#   'Lat': 57.6935,
#   'Lng': 71.1665,
#   'Max Temp': 35.85,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.95,
#   'Country': 'RU'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 76.84,
#   'Current Description': 'clear sky',
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'AU'},
#  {'City': 'Elat',
#   'Lat': 29.5581,
#   'Lng': 34.9482,
#   'Max Temp': 82.24,
#   'Current Description': 'clear sky',
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'IL'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 34.95,
#   'Current Description': 'overcast clouds',
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 23.31,
#   'Country': 'RU'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 24.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 11.77,
#   'Country': 'RU'},
#  {'City': 'Cumra',
#   'Lat': 37.5732,
#   'Lng': 32.7745,
#   'Max Temp': 57.34,
#   'Current Description': 'clear sky',
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 6.62,
#   'Country': 'TR'},
#  {'City': 'Micomeseng',
#   'Lat': 2.1462,
#   'Lng': 10.6164,
#   'Max Temp': 69.49,
#   'Current Description': 'moderate rain',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Country': 'GQ'},
#  {'City': 'Sydney',
#   'Lat': -33.8679,
#   'Lng': 151.2073,
#   'Max Temp': 61.59,
#   'Current Description': 'clear sky',
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'AU'},
#  {'City': 'Khani',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 47.77,
#   'Current Description': 'clear sky',
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.32,
#   'Country': 'GE'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 50.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 21.79,
#   'Country': 'JP'},
#  {'City': 'Koster',
#   'Lat': -25.863,
#   'Lng': 26.8976,
#   'Max Temp': 74.79,
#   'Current Description': 'scattered clouds',
#   'Humidity': 19,
#   'Cloudiness': 36,
#   'Wind Speed': 18.66,
#   'Country': 'ZA'},
#  {'City': 'Isiro',
#   'Lat': 2.7739,
#   'Lng': 27.616,
#   'Max Temp': 70.61,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 1.16,
#   'Country': 'CD'},
#  {'City': 'Miraflores',
#   'Lat': 19.2167,
#   'Lng': -98.8083,
#   'Max Temp': 62.02,
#   'Current Description': 'overcast clouds',
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'MX'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 45.09,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.87,
#   'Country': 'NZ'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 32.29,
#   'Current Description': 'snow',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.96,
#   'Country': 'RU'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 86.61,
#   'Current Description': 'scattered clouds',
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 24.16,
#   'Country': 'BB'},
#  {'City': 'Aviles',
#   'Lat': 43.5547,
#   'Lng': -5.9248,
#   'Max Temp': 61.77,
#   'Current Description': 'broken clouds',
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'ES'},
#  {'City': 'The Pas',
#   'Lat': 53.8251,
#   'Lng': -101.2541,
#   'Max Temp': 26.62,
#   'Current Description': 'broken clouds',
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 63.32,
#   'Current Description': 'clear sky',
#   'Humidity': 52,
#   'Cloudiness': 3,
#   'Wind Speed': 19.01,
#   'Country': 'AU'},
#  {'City': 'Luganville',
#   'Lat': -15.5333,
#   'Lng': 167.1667,
#   'Max Temp': 76.53,
#   'Current Description': 'scattered clouds',
#   'Humidity': 91,
#   'Cloudiness': 30,
#   'Wind Speed': 2.35,
#   'Country': 'VU'},
#  {'City': 'Gurupa',
#   'Lat': -1.405,
#   'Lng': -51.64,
#   'Max Temp': 95.2,
#   'Current Description': 'overcast clouds',
#   'Humidity': 39,
#   'Cloudiness': 94,
#   'Wind Speed': 2.93,
#   'Country': 'BR'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 68.29,
#   'Current Description': 'broken clouds',
#   'Humidity': 74,
#   'Cloudiness': 82,
#   'Wind Speed': 9.91,
#   'Country': 'PT'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 79.95,
#   'Current Description': 'light rain',
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 5.77,
#   'Country': 'SB'},
#  {'City': 'Tatawin',
#   'Lat': 32.9297,
#   'Lng': 10.4518,
#   'Max Temp': 85.08,
#   'Current Description': 'broken clouds',
#   'Humidity': 27,
#   'Cloudiness': 56,
#   'Wind Speed': 9.42,
#   'Country': 'TN'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 77.02,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 23,
#   'Wind Speed': 17.27,
#   'Country': 'PF'},
#  {'City': 'Begunitsy',
#   'Lat': 59.5855,
#   'Lng': 29.3176,
#   'Max Temp': 45.37,
#   'Current Description': 'overcast clouds',
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 19.19,
#   'Country': 'RU'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 75.16,
#   'Current Description': 'clear sky',
#   'Humidity': 46,
#   'Cloudiness': 6,
#   'Wind Speed': 2.39,
#   'Country': 'UY'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 84.16,
#   'Current Description': 'clear sky',
#   'Humidity': 58,
#   'Cloudiness': 2,
#   'Wind Speed': 8.9,
#   'Country': 'CV'},
#  {'City': 'Xining',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 42.42,
#   'Current Description': 'scattered clouds',
#   'Humidity': 76,
#   'Cloudiness': 32,
#   'Wind Speed': 2.84,
#   'Country': 'CN'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 54.19,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 20.04,
#   'Country': 'JP'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 50,
#   'Current Description': 'broken clouds',
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'CA'},
#  {'City': 'Makakilo City',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 73.72,
#   'Current Description': 'clear sky',
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Sechura',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 74.93,
#   'Current Description': 'broken clouds',
#   'Humidity': 63,
#   'Cloudiness': 59,
#   'Wind Speed': 8.88,
#   'Country': 'PE'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 56.28,
#   'Current Description': 'scattered clouds',
#   'Humidity': 76,
#   'Cloudiness': 31,
#   'Wind Speed': 2.44,
#   'Country': 'IT'},
#  {'City': 'San Ramon De La Nueva Oran',
#   'Lat': -23.1322,
#   'Lng': -64.326,
#   'Max Temp': 97.38,
#   'Current Description': 'clear sky',
#   'Humidity': 22,
#   'Cloudiness': 1,
#   'Wind Speed': 4.21,
#   'Country': 'AR'},
#  {'City': 'Gigmoto',
#   'Lat': 13.7796,
#   'Lng': 124.39,
#   'Max Temp': 80.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.29,
#   'Country': 'PH'},
#  {'City': 'Sorata',
#   'Lat': -15.7667,
#   'Lng': -68.6333,
#   'Max Temp': 61.02,
#   'Current Description': 'scattered clouds',
#   'Humidity': 50,
#   'Cloudiness': 33,
#   'Wind Speed': 10.25,
#   'Country': 'BO'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 65.1,
#   'Current Description': 'clear sky',
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'ZA'},
#  {'City': 'Straumen',
#   'Lat': 63.8709,
#   'Lng': 11.2999,
#   'Max Temp': 42.51,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 93,
# ...
#   'Max Temp': 77.36,
#   'Current Description': 'clear sky',
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 8.32,
#   'Country': 'LY'},
#  {'City': 'Kashary',
#   'Lat': 49.04,
#   'Lng': 41.0056,
#   'Max Temp': 55.27,
#   'Current Description': 'few clouds',
#   'Humidity': 64,
#   'Cloudiness': 14,
#   'Wind Speed': 8.28,
#   'Country': 'RU'},
#  {'City': 'Lengshuitan',
#   'Lat': 26.4111,
#   'Lng': 111.5956,
#   'Max Temp': 52.74,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Country': 'CN'},
#  {'City': 'Ankara',
#   'Lat': 39.9199,
#   'Lng': 32.8543,
#   'Max Temp': 61.21,
#   'Current Description': 'clear sky',
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'TR'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 91.42,
#   'Current Description': 'clear sky',
#   'Humidity': 15,
#   'Cloudiness': 2,
#   'Wind Speed': 4.85,
#   'Country': 'ML'},
#  {'City': 'Sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 83.77,
#   'Current Description': 'clear sky',
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 14.34,
#   'Country': 'SA'},
#  {'City': 'Wattegama',
#   'Lat': 6.7989,
#   'Lng': 81.4808,
#   'Max Temp': 75.81,
#   'Current Description': 'few clouds',
#   'Humidity': 92,
#   'Cloudiness': 13,
#   'Wind Speed': 2.46,
#   'Country': 'LK'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 61.39,
#   'Current Description': 'overcast clouds',
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'RO'},
#  {'City': 'Kathu',
#   'Lat': 7.9178,
#   'Lng': 98.3332,
#   'Max Temp': 83.7,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Country': 'TH'},
#  {'City': 'Mortka',
#   'Lat': 59.3322,
#   'Lng': 66.0214,
#   'Max Temp': 37.35,
#   'Current Description': 'light rain',
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'RU'},
#  {'City': 'Maniwaki',
#   'Lat': 46.3834,
#   'Lng': -75.966,
#   'Max Temp': 41.54,
#   'Current Description': 'scattered clouds',
#   'Humidity': 75,
#   'Cloudiness': 33,
#   'Wind Speed': 10.36,
#   'Country': 'CA'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 64.85,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 4,
#   'Wind Speed': 8.37,
#   'Country': 'NA'},
#  {'City': 'Yazman',
#   'Lat': 29.1212,
#   'Lng': 71.7446,
#   'Max Temp': 84.27,
#   'Current Description': 'clear sky',
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 15.12,
#   'Country': 'PK'},
#  {'City': 'Qinnan',
#   'Lat': 33.2531,
#   'Lng': 119.9133,
#   'Max Temp': 52.9,
#   'Current Description': 'light rain',
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 2.89,
#   'Country': 'CN'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 73.85,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 8.93,
#   'Country': 'NC'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 72.21,
#   'Current Description': 'clear sky',
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95,
#   'Country': 'NC'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 71.78,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 7.83,
#   'Country': 'BR'},
#  {'City': 'Guadalajara',
#   'Lat': 20.6667,
#   'Lng': -103.3333,
#   'Max Temp': 69.98,
#   'Current Description': 'broken clouds',
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'MX'},
#  {'City': 'Cerrito',
#   'Lat': 6.8432,
#   'Lng': -72.694,
#   'Max Temp': 60.19,
#   'Current Description': 'broken clouds',
#   'Humidity': 78,
#   'Cloudiness': 69,
#   'Wind Speed': 1.79,
#   'Country': 'CO'},
#  {'City': 'Homer',
#   'Lat': 59.6425,
#   'Lng': -151.5483,
#   'Max Temp': 38.77,
#   'Current Description': 'clear sky',
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Diego De Almagro',
#   'Lat': -26.3667,
#   'Lng': -70.05,
#   'Max Temp': 77.47,
#   'Current Description': 'clear sky',
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 11.95,
#   'Country': 'CL'},
#  {'City': 'Srivardhan',
#   'Lat': 18.0333,
#   'Lng': 73.0167,
#   'Max Temp': 77.41,
#   'Current Description': 'moderate rain',
#   'Humidity': 73,
#   'Cloudiness': 17,
#   'Wind Speed': 4.94,
#   'Country': 'IN'},
#  {'City': 'Great Falls',
#   'Lat': 47.5002,
#   'Lng': -111.3008,
#   'Max Temp': 61.68,
#   'Current Description': 'clear sky',
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US'},
#  {'City': 'Tambura',
#   'Lat': 5.6,
#   'Lng': 27.4667,
#   'Max Temp': 74.48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.42,
#   'Country': 'SS'},
#  {'City': 'Petrachioaia',
#   'Lat': 44.5833,
#   'Lng': 26.3,
#   'Max Temp': 66.13,
#   'Current Description': 'clear sky',
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'RO'},
#  {'City': 'Chinsali',
#   'Lat': -10.5414,
#   'Lng': 32.0816,
#   'Max Temp': 79.36,
#   'Current Description': 'broken clouds',
#   'Humidity': 28,
#   'Cloudiness': 71,
#   'Wind Speed': 6.85,
#   'Country': 'ZM'},
#  {'City': 'Terracina',
#   'Lat': 41.2863,
#   'Lng': 13.2217,
#   'Max Temp': 69.98,
#   'Current Description': 'broken clouds',
#   'Humidity': 87,
#   'Cloudiness': 79,
#   'Wind Speed': 8.99,
#   'Country': 'IT'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 67.01,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'PE'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 76.23,
#   'Current Description': 'overcast clouds',
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 15.37,
#   'Country': 'ZA'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 62.47,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 93,
#   'Wind Speed': 3.24,
#   'Country': 'ZA'},
#  {'City': 'Churapcha',
#   'Lat': 62.0025,
#   'Lng': 132.4325,
#   'Max Temp': 25.83,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.34,
#   'Country': 'RU'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 80.04,
#   'Current Description': 'few clouds',
#   'Humidity': 83,
#   'Cloudiness': 14,
#   'Wind Speed': 7.18,
#   'Country': 'LK'},
#  {'City': 'Barauna',
#   'Lat': -5.08,
#   'Lng': -37.6167,
#   'Max Temp': 92.3,
#   'Current Description': 'overcast clouds',
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 14.61,
#   'Country': 'BR'},
#  {'City': 'Olavarria',
#   'Lat': -36.8927,
#   'Lng': -60.3225,
#   'Max Temp': 59.02,
#   'Current Description': 'light rain',
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Country': 'AR'},
#  {'City': 'Portlethen',
#   'Lat': 57.0547,
#   'Lng': -2.1307,
#   'Max Temp': 44.37,
#   'Current Description': 'few clouds',
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'GB'},
#  {'City': 'Borzna',
#   'Lat': 51.2546,
#   'Lng': 32.4269,
#   'Max Temp': 50.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 51,
#   'Cloudiness': 28,
#   'Wind Speed': 10.76,
#   'Country': 'UA'},
#  {'City': 'Balkhash',
#   'Lat': 46.844,
#   'Lng': 74.9804,
#   'Max Temp': 41.59,
#   'Current Description': 'overcast clouds',
#   'Humidity': 42,
#   'Cloudiness': 93,
#   'Wind Speed': 14.05,
#   'Country': 'KZ'},
#  {'City': 'Suksun',
#   'Lat': 57.1431,
#   'Lng': 57.3949,
#   'Max Temp': 46.8,
#   'Current Description': 'light rain',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 19.89,
#   'Country': 'RU'},
#  {'City': 'Sahuaripa',
#   'Lat': 29.05,
#   'Lng': -109.2333,
#   'Max Temp': 84.6,
#   'Current Description': 'clear sky',
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 2.19,
#   'Country': 'MX'},
#  {'City': 'Stokmarknes',
#   'Lat': 68.5646,
#   'Lng': 14.9108,
#   'Max Temp': 36.5,
#   'Current Description': 'clear sky',
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'NO'},
#  {'City': 'Janoshaza',
#   'Lat': 47.1194,
#   'Lng': 17.165,
#   'Max Temp': 55.08,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'HU'},
#  {'City': 'Saint-Michel-Des-Saints',
#   'Lat': 46.6834,
#   'Lng': -73.9159,
#   'Max Temp': 41.94,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 10.13,
#   'Country': 'CA'},
#  {'City': 'Puerto Madero',
#   'Lat': 14.7208,
#   'Lng': -92.4215,
#   'Max Temp': 84.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'MX'},
#  {'City': 'Nouakchott',
#   'Lat': 18.0858,
#   'Lng': -15.9785,
#   'Max Temp': 96.73,
#   'Current Description': 'overcast clouds',
#   'Humidity': 27,
#   'Cloudiness': 94,
#   'Wind Speed': 11.18,
#   'Country': 'MR'},
#  {'City': 'Lydenburg',
#   'Lat': -25.0978,
#   'Lng': 30.4597,
#   'Max Temp': 75.27,
#   'Current Description': 'scattered clouds',
#   'Humidity': 41,
#   'Cloudiness': 31,
#   'Wind Speed': 1.54,
#   'Country': 'ZA'},
#  {'City': 'Saint-Leu',
#   'Lat': -21.15,
#   'Lng': 55.2833,
#   'Max Temp': 76.06,
#   'Current Description': 'scattered clouds',
#   'Humidity': 94,
#   'Cloudiness': 31,
#   'Wind Speed': 1.81,
#   'Country': 'RE'},
#  {'City': 'Burns Lake',
#   'Lat': 54.2331,
#   'Lng': -125.7533,
#   'Max Temp': 44.02,
#   'Current Description': 'broken clouds',
#   'Humidity': 85,
#   'Cloudiness': 58,
#   'Wind Speed': 4.07,
#   'Country': 'CA'},
#  {'City': 'Radyvyliv',
#   'Lat': 50.1299,
#   'Lng': 25.2558,
#   'Max Temp': 50.18,
#   'Current Description': 'overcast clouds',
#   'Humidity': 53,
#   'Cloudiness': 89,
#   'Wind Speed': 8.08,
#   'Country': 'UA'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 80.01,
#   'Current Description': 'light rain',
#   'Humidity': 79,
#   'Cloudiness': 54,
#   'Wind Speed': 9.75,
#   'Country': 'SO'},
#  {'City': 'Collingwood',
#   'Lat': 44.4834,
#   'Lng': -80.2164,
#   'Max Temp': 44.89,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 98,
#   'Wind Speed': 9.22,
#   'Country': 'CA'},
#  {'City': 'Koshki',
#   'Lat': 54.2091,
#   'Lng': 50.4677,
#   'Max Temp': 52.83,
#   'Current Description': 'overcast clouds',
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 18.75,
#   'Country': 'RU'},
#  {'City': 'Messias',
#   'Lat': -9.3833,
#   'Lng': -35.8417,
#   'Max Temp': 89.31,
#   'Current Description': 'scattered clouds',
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'BR'},
#  {'City': 'Baruun-Urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': 32.74,
#   'Current Description': 'clear sky',
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 8.52,
#   'Country': 'MN'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': 6.17,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 2.24,
#   'Country': 'RU'},
#  {'City': 'Mareeba',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 74.12,
#   'Current Description': 'broken clouds',
#   'Humidity': 95,
#   'Cloudiness': 72,
#   'Wind Speed': 2.39,
#   'Country': 'AU'},
#  {'City': 'Alapur',
#   'Lat': 27.9555,
#   'Lng': 79.2269,
#   'Max Temp': 74.19,
#   'Current Description': 'clear sky',
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 0.78,
#   'Country': 'IN'},
#  {'City': 'Storforshei',
#   'Lat': 66.4043,
#   'Lng': 14.5233,
#   'Max Temp': 34.66,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'NO'},
#  {'City': 'Butembo',
#   'Lat': 0.15,
#   'Lng': 29.2833,
#   'Max Temp': 59.04,
#   'Current Description': 'light rain',
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.28,
#   'Country': 'CD'},
#  {'City': 'Chute-Aux-Outardes',
#   'Lat': 49.1168,
#   'Lng': -68.399,
#   'Max Temp': 57.51,
#   'Current Description': 'light rain',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'CA'},
#  {'City': 'Altavas',
#   'Lat': 11.538,
#   'Lng': 122.487,
#   'Max Temp': 76.33,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 1.97,
#   'Country': 'PH'},
#  {'City': 'West Fargo',
#   'Lat': 46.875,
#   'Lng': -96.9004,
#   'Max Temp': 43.02,
#   'Current Description': 'clear sky',
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 5.99,
#   'Country': 'US'},
#  {'City': 'Galion',
#   'Lat': 40.7337,
#   'Lng': -82.7899,
#   'Max Temp': 48.2,
#   'Current Description': 'scattered clouds',
#   'Humidity': 82,
#   'Cloudiness': 49,
#   'Wind Speed': 7.85,
#   'Country': 'US'},
#  {'City': 'Teya',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 38.26,
#   'Current Description': 'overcast clouds',
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15,
#   'Country': 'RU'},
#  {'City': 'Qeshm',
#   'Lat': 26.9581,
#   'Lng': 56.2719,
#   'Max Temp': 82.29,
#   'Current Description': 'clear sky',
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 7.85,
#   'Country': 'IR'},
#  {'City': 'Valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 64.63,
#   'Current Description': 'few clouds',
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'CL'},
#  {'City': 'Tahe',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': 32.83,
#   'Current Description': 'scattered clouds',
#   'Humidity': 78,
#   'Cloudiness': 45,
#   'Wind Speed': 4.81,
#   'Country': 'CN'},
#  {'City': 'Takayama',
#   'Lat': 36.1333,
#   'Lng': 137.25,
#   'Max Temp': 49.46,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.48,
#   'Country': 'JP'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 70.29,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 5,
#   'Wind Speed': 19.17,
#   'Country': 'MR'},
#  {'City': 'Ursulo Galvan',
#   'Lat': 22.7333,
#   'Lng': -98.3,
#   'Max Temp': 85.51,
#   'Current Description': 'clear sky',
#   'Humidity': 67,
#   'Cloudiness': 6,
#   'Wind Speed': 2.35,
#   'Country': 'MX'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 39.18,
#   'Current Description': 'broken clouds',
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CA'},
#  {'City': 'Ocampo',
#   'Lat': 21.65,
#   'Lng': -101.5,
#   'Max Temp': 64.96,
#   'Current Description': 'broken clouds',
#   'Humidity': 63,
#   'Cloudiness': 53,
#   'Wind Speed': 8.99,
#   'Country': 'MX'},
#  {'City': 'Ust-Kuyga',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': -2.9,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 95,
#   'Wind Speed': 3.04,
#   'Country': 'RU'},
#  {'City': 'Aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 88.9,
#   'Current Description': 'clear sky',
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'EG'},
#  {'City': 'Bonito',
#   'Lat': -21.1211,
#   'Lng': -56.4819,
#   'Max Temp': 99.12,
#   'Current Description': 'few clouds',
#   'Humidity': 23,
#   'Cloudiness': 11,
#   'Wind Speed': 5.39,
#   'Country': 'BR'},
#  {'City': 'Patos De Minas',
#   'Lat': -18.5789,
#   'Lng': -46.5181,
#   'Max Temp': 86.31,
#   'Current Description': 'scattered clouds',
#   'Humidity': 33,
#   'Cloudiness': 35,
#   'Wind Speed': 9.17,
#   'Country': 'BR'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 27.61,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Izumo',
#   'Lat': 35.3667,
#   'Lng': 132.7667,
#   'Max Temp': 57.15,
#   'Current Description': 'moderate rain',
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 10.85,
#   'Country': 'JP'},
#  {'City': 'Kollam',
#   'Lat': 8.8833,
#   'Lng': 76.6,
#   'Max Temp': 82.27,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 63,
#   'Wind Speed': 4.27,
#   'Country': 'IN'},
#  {'City': 'Severnoye',
#   'Lat': 56.3491,
#   'Lng': 78.3619,
#   'Max Temp': 36.5,
#   'Current Description': 'broken clouds',
#   'Humidity': 61,
#   'Cloudiness': 61,
#   'Wind Speed': 16.58,
#   'Country': 'RU'},
#  {'City': 'Shakawe',
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp': 88.2,
#   'Current Description': 'broken clouds',
#   'Humidity': 32,
#   'Cloudiness': 63,
#   'Wind Speed': 6.62,
#   'Country': 'BW'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp Current Description  \
# 0            Atuona  -9.8000 -139.0333     78.01    scattered clouds
# 1        Butaritari   3.0707  172.7902     81.77       moderate rain
# 2           Rikitea -23.1203 -134.9692     73.89          light rain
# 3  Pontal Do Parana -25.6533  -48.5128     86.20    scattered clouds
# 4          Westport  41.1415  -73.3579     71.46           clear sky
# 5       Capinopolis -18.6819  -49.5697     91.02           clear sky
# 6        Kaitangata -46.2817  169.8464     44.46     overcast clouds
# 7             Dubbo -32.2500  148.6167     60.93           clear sky
# 8       Port Alfred -33.5906   26.8910     65.08       broken clouds
# 9          Coquimbo -29.9533  -71.3436     60.53          few clouds
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        76          33       21.88      PF
# 1        79          19       16.82      KI
# 2        81         100       24.81      PF
# 3        38          40        5.75      BR
# 4        59           1        1.01      US
# 5        28           2        6.89      BR
# 6        95         100        2.51      NZ
# 7        82           0       13.80      AU
# 8        80          61        8.79      ZA
# 9        67          20       12.66      CL

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-7c55ac381a67> in <module>
#       1 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       2
# ----> 3 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3401             doublequote=doublequote,
#    3402             escapechar=escapechar,
# -> 3403             storage_options=storage_options,
#    3404         )
#    3405
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
